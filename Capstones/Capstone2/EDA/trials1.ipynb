# %%
# !pip install geopandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Ignoring invalid distribution -cxt (/home/jj/.local/lib/python3.10/site-packages)
# ...
# WARNING: Ignoring invalid distribution -cxt (/home/jj/.local/lib/python3.10/site-packages)
#
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
import geopandas as gpd

# Cargar el shapefile de México
mexico_shapefile_path = './dest_2010gw/dest_2010gw.shp'   # Reemplaza con la ruta de tu shapefile
mexico = gpd.read_file(mexico_shapefile_path)

# Mostrar las primeras filas para revisar las columnas
mexico.ENTIDAD.unique()
# Out:
# array(['BAJA CALIFORNIA', 'SONORA', 'CHIHUAHUA', 'COAHUILA DE ZARAGOZA',
#        'BAJA CALIFORNIA SUR', 'NUEVO LEON', 'TAMAULIPAS', 'SINALOA',
#        'DURANGO', 'ZACATECAS', 'SAN LUIS POTOSI', 'NAYARIT', 'JALISCO',
#        'VERACRUZ DE IGNACIO DE LA LLAVE', 'AGUASCALIENTES',
#        'QUINTANA ROO', 'YUCATAN', 'GUANAJUATO', 'QUERETARO DE ARTEAGA',
#        'CAMPECHE', 'HIDALGO', 'PUEBLA', 'MICHOACAN DE OCAMPO', 'MEXICO',
#        'TLAXCALA', 'DISTRITO FEDERAL', 'COLIMA', 'MORELOS', 'TABASCO',
#        'GUERRERO', 'OAXACA', 'CHIAPAS'], dtype=object)

# %%
# Diccionario de mapeo manual
entity_mapping = {
    'BAJA CALIFORNIA': 'BAJA CALIFORNIA',
    'SONORA': 'SONORA',
    'CHIHUAHUA': 'CHIHUAHUA',
    'COAHUILA DE ZARAGOZA': 'COAHUILA',
    'BAJA CALIFORNIA SUR': 'BAJA CALIFORNIA SUR',
    'NUEVO LEON': 'NUEVO LEÓN',
    'TAMAULIPAS': 'TAMAULIPAS',
    'SINALOA': 'SINALOA',
    'DURANGO': 'DURANGO',
    'ZACATECAS': 'ZACATECAS',
    'SAN LUIS POTOSI': 'SAN LUIS POTOSÍ',
    'NAYARIT': 'NAYARIT',
    'JALISCO': 'JALISCO',
    'VERACRUZ DE IGNACIO DE LA LLAVE': 'VERACRUZ',
    'AGUASCALIENTES': 'AGUASCALIENTES',
    'QUINTANA ROO': 'QUINTANA ROO',
    'YUCATAN': 'YUCATÁN',
    'GUANAJUATO': 'GUANAJUATO',
    'QUERETARO DE ARTEAGA': 'QUERÉTARO',
    'CAMPECHE': 'CAMPECHE',
    'HIDALGO': 'HIDALGO',
    'PUEBLA': 'PUEBLA',
    'MICHOACAN DE OCAMPO': 'MICHOACÁN',
    'MEXICO': 'MÉXICO',
    'TLAXCALA': 'TLAXCALA',
    'DISTRITO FEDERAL': 'CIUDAD DE MÉXICO',
    'COLIMA': 'COLIMA',
    'MORELOS': 'MORELOS',
    'TABASCO': 'TABASCO',
    'GUERRERO': 'GUERRERO',
    'OAXACA': 'OAXACA',
    'CHIAPAS': 'CHIAPAS'
}

# Aplicar el mapeo a los nombres de las entidades en el shapefile
mexico['ENTIDAD'] = mexico['ENTIDAD'].replace(entity_mapping)

# Verificar el mapeo
print(mexico['ENTIDAD'].unique())
# Out:
# ['BAJA CALIFORNIA' 'SONORA' 'CHIHUAHUA' 'COAHUILA' 'BAJA CALIFORNIA SUR'
#  'NUEVO LEÓN' 'TAMAULIPAS' 'SINALOA' 'DURANGO' 'ZACATECAS'
#  'SAN LUIS POTOSÍ' 'NAYARIT' 'JALISCO' 'VERACRUZ' 'AGUASCALIENTES'
#  'QUINTANA ROO' 'YUCATÁN' 'GUANAJUATO' 'QUERÉTARO' 'CAMPECHE' 'HIDALGO'
#  'PUEBLA' 'MICHOACÁN' 'MÉXICO' 'TLAXCALA' 'CIUDAD DE MÉXICO' 'COLIMA'
#  'MORELOS' 'TABASCO' 'GUERRERO' 'OAXACA' 'CHIAPAS']

# %%
import pandas as pd

# Cargar los datos de votos
file_path = 'ELECTIONS_vs_SOCIODEMOGRAPHICS_ALT2.csv'
data = pd.read_csv(file_path)

# Asegurar que los nombres de los estados estén en mayúsculas
data['ENTIDAD'] = data['ENTIDAD'].str.upper()

# Mostrar los nombres de las entidades únicas en el archivo CSV
print(data['ENTIDAD'].unique())
# Out:
# ['AGUASCALIENTES' 'BAJA CALIFORNIA' 'BAJA CALIFORNIA SUR' 'CAMPECHE'
#  'CHIAPAS' 'CHIHUAHUA' 'CIUDAD DE MEXICO' 'COAHUILA' 'COLIMA' 'DURANGO'
#  'GUANAJUATO' 'GUERRERO' 'HIDALGO' 'JALISCO' 'MEXICO' 'MICHOACAN'
#  'MORELOS' 'NAYARIT' 'NUEVO LEON' 'OAXACA' 'PUEBLA' 'QUERETARO'
#  'QUINTANA ROO' 'SAN LUIS POTOSI' 'SINALOA' 'SONORA' 'TABASCO'
#  'TAMAULIPAS' 'TLAXCALA' 'VERACRUZ' 'YUCATAN' 'ZACATECAS']

# %%
import geopandas as gpd
import pandas as pd

# Cargar el shapefile de México
mexico_shapefile_path = './dest_2010gw/dest_2010gw.shp'
mexico = gpd.read_file(mexico_shapefile_path)

# Diccionario de mapeo manual ajustado
entity_mapping = {
    'BAJA CALIFORNIA': 'BAJA CALIFORNIA',
    'SONORA': 'SONORA',
    'CHIHUAHUA': 'CHIHUAHUA',
    'COAHUILA DE ZARAGOZA': 'COAHUILA',
    'BAJA CALIFORNIA SUR': 'BAJA CALIFORNIA SUR',
    'NUEVO LEON': 'NUEVO LEÓN',
    'TAMAULIPAS': 'TAMAULIPAS',
    'SINALOA': 'SINALOA',
    'DURANGO': 'DURANGO',
    'ZACATECAS': 'ZACATECAS',
    'SAN LUIS POTOSI': 'SAN LUIS POTOSÍ',
    'NAYARIT': 'NAYARIT',
    'JALISCO': 'JALISCO',
    'VERACRUZ DE IGNACIO DE LA LLAVE': 'VERACRUZ',
    'AGUASCALIENTES': 'AGUASCALIENTES',
    'QUINTANA ROO': 'QUINTANA ROO',
    'YUCATAN': 'YUCATÁN',
    'GUANAJUATO': 'GUANAJUATO',
    'QUERETARO DE ARTEAGA': 'QUERÉTARO',
    'CAMPECHE': 'CAMPECHE',
    'HIDALGO': 'HIDALGO',
    'PUEBLA': 'PUEBLA',
    'MICHOACAN DE OCAMPO': 'MICHOACÁN',
    'MEXICO': 'MÉXICO',
    'TLAXCALA': 'TLAXCALA',
    'DISTRITO FEDERAL': 'CIUDAD DE MÉXICO',
    'COLIMA': 'COLIMA',
    'MORELOS': 'MORELOS',
    'TABASCO': 'TABASCO',
    'GUERRERO': 'GUERRERO',
    'OAXACA': 'OAXACA',
    'CHIAPAS': 'CHIAPAS'
}

# Aplicar el mapeo a los nombres de las entidades en el shapefile
mexico['ENTIDAD'] = mexico['ENTIDAD'].replace(entity_mapping)

# Cargar los datos de votos
file_path = 'ELECTIONS_vs_SOCIODEMOGRAPHICS_ALT2.csv'
data = pd.read_csv(file_path)

# Asegurar que los nombres de los estados coincidan entre el shapefile y los datos
data['ENTIDAD'] = data['ENTIDAD'].str.upper()

# Crear una columna para el ganador en cada estado
data['Winner'] = data[['COMPETITOR_Votes_2024', 'Xochitl_Opposition_Votes', 'Maynez_Independant_Votes']].idxmax(axis=1)

# Mapping winners to colors
color_mapping = {
    'COMPETITOR_Votes_2024': 'brown',  # Claudia Sheinbaum
    'Xochitl_Opposition_Votes': 'blue',  # Xochitl Galvez
    'Maynez_Independant_Votes': 'orange'  # Maynez
}
data['color'] = data['Winner'].map(color_mapping)

# Unir los datos con el shapefile de México
mexico = mexico.merge(data, on='ENTIDAD', how='left')

# Verificar la unión
print(mexico[['ENTIDAD', 'color']].head())

# Crear el gráfico
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 1, figsize=(15, 15))
mexico.boundary.plot(ax=ax, linewidth=1)
mexico.plot(column='color', ax=ax, legend=True, categorical=True, legend_kwds={'loc': 'lower left'}, edgecolor='black')

# Eliminar los ejes
ax.set_axis_off()

plt.show()
# Out:
#            ENTIDAD  color
# 0  BAJA CALIFORNIA  brown
# 1  BAJA CALIFORNIA  brown
# 2  BAJA CALIFORNIA  brown
# 3  BAJA CALIFORNIA  brown
# 4  BAJA CALIFORNIA  brown

# %% [markdown]
# Los estados en blanco son los estados que tienen acento un 1 data frame y en el otro no!!

# %%
pip install unidecode
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Ignoring invalid distribution -cxt (/home/jj/.local/lib/python3.10/site-packages)
# ...
# WARNING: Ignoring invalid distribution -cxt (/home/jj/.local/lib/python3.10/site-packages)
#
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
entity_mapping = {
    'BAJA CALIFORNIA': 'BAJA CALIFORNIA',
    'SONORA': 'SONORA',
    'CHIHUAHUA': 'CHIHUAHUA',
    'COAHUILA DE ZARAGOZA': 'COAHUILA',
    'BAJA CALIFORNIA SUR': 'BAJA CALIFORNIA SUR',
    'NUEVO LEON': 'NUEVO LEON',
    'TAMAULIPAS': 'TAMAULIPAS',
    'SINALOA': 'SINALOA',
    'DURANGO': 'DURANGO',
    'ZACATECAS': 'ZACATECAS',
    'SAN LUIS POTOSI': 'SAN LUIS POTOSI',
    'NAYARIT': 'NAYARIT',
    'JALISCO': 'JALISCO',
    'VERACRUZ DE IGNACIO DE LA LLAVE': 'VERACRUZ',
    'AGUASCALIENTES': 'AGUASCALIENTES',
    'QUINTANA ROO': 'QUINTANA ROO',
    'YUCATAN': 'YUCATAN',
    'GUANAJUATO': 'GUANAJUATO',
    'QUERETARO DE ARTEAGA': 'QUERETARO',
    'CAMPECHE': 'CAMPECHE',
    'HIDALGO': 'HIDALGO',
    'PUEBLA': 'PUEBLA',
    'MICHOACAN DE OCAMPO': 'MICHOACAN',
    'MEXICO': 'MEXICO',
    'TLAXCALA': 'TLAXCALA',
    'DISTRITO FEDERAL': 'CIUDAD DE MEXICO',
    'COLIMA': 'COLIMA',
    'MORELOS': 'MORELOS',
    'TABASCO': 'TABASCO',
    'GUERRERO': 'GUERRERO',
    'OAXACA': 'OAXACA',
    'CHIAPAS': 'CHIAPAS'
}

# %%
import geopandas as gpd
import pandas as pd
from unidecode import unidecode

# Cargar el shapefile de México
mexico_shapefile_path = './dest_2010gw/dest_2010gw.shp'
mexico = gpd.read_file(mexico_shapefile_path)

# Normalizar y mapear los nombres de las entidades en el shapefile
mexico['ENTIDAD'] = mexico['ENTIDAD'].apply(unidecode).str.upper().replace(entity_mapping)

# Verificar los nombres de las entidades en el shapefile después de normalizar y mapear
print("Entidades en el shapefile después de normalizar y mapear:")
print(mexico['ENTIDAD'].unique())

# Cargar los datos de votos
file_path = 'ELECTIONS_vs_SOCIODEMOGRAPHICS_ALT2.csv'
data = pd.read_csv(file_path)

# Normalizar los nombres de las entidades en el CSV
data['ENTIDAD'] = data['ENTIDAD'].apply(unidecode).str.upper()

# Verificar los nombres de las entidades en el CSV después de normalizar
print("Entidades en el CSV después de normalizar:")
print(data['ENTIDAD'].unique())

# Crear una columna para el ganador en cada estado
data['Winner'] = data[['COMPETITOR_Votes_2024', 'Xochitl_Opposition_Votes', 'Maynez_Independant_Votes']].idxmax(axis=1)

# Mapping winners to colors
color_mapping = {
    'COMPETITOR_Votes_2024': 'brown',  # Claudia Sheinbaum
    'Xochitl_Opposition_Votes': 'blue',  # Xochitl Galvez
    'Maynez_Independant_Votes': 'orange'  # Maynez
}
data['color'] = data['Winner'].map(color_mapping)

# Unir los datos con el shapefile de México
mexico = mexico.merge(data, on='ENTIDAD', how='left')

# Verificar la unión
print(mexico[['ENTIDAD', 'color']].head())

# Crear el gráfico
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 1, figsize=(15, 15))
mexico.boundary.plot(ax=ax, linewidth=1)
mexico.plot(column='color', ax=ax, legend=True, categorical=True, legend_kwds={'loc': 'lower left'}, edgecolor='black')

# Eliminar los ejes
ax.set_axis_off()

plt.show()
# Out:
# Entidades en el shapefile después de normalizar y mapear:
# ['BAJA CALIFORNIA' 'SONORA' 'CHIHUAHUA' 'COAHUILA' 'BAJA CALIFORNIA SUR'
#  'NUEVO LEON' 'TAMAULIPAS' 'SINALOA' 'DURANGO' 'ZACATECAS'
#  'SAN LUIS POTOSI' 'NAYARIT' 'JALISCO' 'VERACRUZ' 'AGUASCALIENTES'
#  'QUINTANA ROO' 'YUCATAN' 'GUANAJUATO' 'QUERETARO' 'CAMPECHE' 'HIDALGO'
#  'PUEBLA' 'MICHOACAN' 'MEXICO' 'TLAXCALA' 'CIUDAD DE MEXICO' 'COLIMA'
#  'MORELOS' 'TABASCO' 'GUERRERO' 'OAXACA' 'CHIAPAS']
# Entidades en el CSV después de normalizar:
# ['AGUASCALIENTES' 'BAJA CALIFORNIA' 'BAJA CALIFORNIA SUR' 'CAMPECHE'
#  'CHIAPAS' 'CHIHUAHUA' 'CIUDAD DE MEXICO' 'COAHUILA' 'COLIMA' 'DURANGO'
#  'GUANAJUATO' 'GUERRERO' 'HIDALGO' 'JALISCO' 'MEXICO' 'MICHOACAN'
#  'MORELOS' 'NAYARIT' 'NUEVO LEON' 'OAXACA' 'PUEBLA' 'QUERETARO'
#  'QUINTANA ROO' 'SAN LUIS POTOSI' 'SINALOA' 'SONORA' 'TABASCO'
#  'TAMAULIPAS' 'TLAXCALA' 'VERACRUZ' 'YUCATAN' 'ZACATECAS']
#            ENTIDAD  color
# 0  BAJA CALIFORNIA  brown
# 1  BAJA CALIFORNIA  brown
# ...

# %%
import geopandas as gpd
import pandas as pd
from unidecode import unidecode

# Cargar el shapefile de México
mexico_shapefile_path = './dest_2010gw/dest_2010gw.shp'
mexico = gpd.read_file(mexico_shapefile_path)

# Normalizar y mapear los nombres de las entidades en el shapefile
entity_mapping = {
    'BAJA CALIFORNIA': 'BAJA CALIFORNIA',
    'SONORA': 'SONORA',
    'CHIHUAHUA': 'CHIHUAHUA',
    'COAHUILA DE ZARAGOZA': 'COAHUILA',
    'BAJA CALIFORNIA SUR': 'BAJA CALIFORNIA SUR',
    'NUEVO LEON': 'NUEVO LEON',
    'TAMAULIPAS': 'TAMAULIPAS',
    'SINALOA': 'SINALOA',
    'DURANGO': 'DURANGO',
    'ZACATECAS': 'ZACATECAS',
    'SAN LUIS POTOSI': 'SAN LUIS POTOSI',
    'NAYARIT': 'NAYARIT',
    'JALISCO': 'JALISCO',
    'VERACRUZ DE IGNACIO DE LA LLAVE': 'VERACRUZ',
    'AGUASCALIENTES': 'AGUASCALIENTES',
    'QUINTANA ROO': 'QUINTANA ROO',
    'YUCATAN': 'YUCATAN',
    'GUANAJUATO': 'GUANAJUATO',
    'QUERETARO DE ARTEAGA': 'QUERETARO',
    'CAMPECHE': 'CAMPECHE',
    'HIDALGO': 'HIDALGO',
    'PUEBLA': 'PUEBLA',
    'MICHOACAN DE OCAMPO': 'MICHOACAN',
    'MEXICO': 'MEXICO',
    'TLAXCALA': 'TLAXCALA',
    'DISTRITO FEDERAL': 'CIUDAD DE MEXICO',
    'COLIMA': 'COLIMA',
    'MORELOS': 'MORELOS',
    'TABASCO': 'TABASCO',
    'GUERRERO': 'GUERRERO',
    'OAXACA': 'OAXACA',
    'CHIAPAS': 'CHIAPAS'
}
mexico['ENTIDAD'] = mexico['ENTIDAD'].apply(unidecode).str.upper().replace(entity_mapping)

# Verificar los nombres de las entidades en el shapefile después de normalizar y mapear
print("Entidades en el shapefile después de normalizar y mapear:")
print(mexico['ENTIDAD'].unique())

# Cargar los datos de votos
file_path = 'ELECTIONS_vs_SOCIODEMOGRAPHICS_ALT2.csv'
data = pd.read_csv(file_path)

# Normalizar los nombres de las entidades en el CSV
data['ENTIDAD'] = data['ENTIDAD'].apply(unidecode).str.upper()

# Verificar los nombres de las entidades en el CSV después de normalizar
print("Entidades en el CSV después de normalizar:")
print(data['ENTIDAD'].unique())

# Crear una columna para el ganador en cada estado
data['Winner'] = data[['COMPETITOR_Votes_2024', 'Xochitl_Opposition_Votes', 'Maynez_Independant_Votes']].idxmax(axis=1)

# Mapping winners to colors using hex color codes
color_mapping = {
    'COMPETITOR_Votes_2024': '#8B4513',  # Claudia Sheinbaum - Brown
    'Xochitl_Opposition_Votes': '#0000FF',  # Xochitl Galvez - Blue
    'Maynez_Independant_Votes': '#FFA500'  # Maynez - Orange
}
data['color'] = data['Winner'].map(color_mapping)

# Unir los datos con el shapefile de México
mexico = mexico.merge(data, on='ENTIDAD', how='left')

# Verificar la unión
print(mexico[['ENTIDAD', 'color']].head())

# Crear el gráfico
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 1, figsize=(15, 15))
mexico.boundary.plot(ax=ax, linewidth=1)
mexico.plot(column='color', ax=ax, legend=True, categorical=True, legend_kwds={'loc': 'lower left'}, edgecolor='black')

# Eliminar los ejes
ax.set_axis_off()

plt.show()
# Out:
# Entidades en el shapefile después de normalizar y mapear:
# ['BAJA CALIFORNIA' 'SONORA' 'CHIHUAHUA' 'COAHUILA' 'BAJA CALIFORNIA SUR'
#  'NUEVO LEON' 'TAMAULIPAS' 'SINALOA' 'DURANGO' 'ZACATECAS'
#  'SAN LUIS POTOSI' 'NAYARIT' 'JALISCO' 'VERACRUZ' 'AGUASCALIENTES'
#  'QUINTANA ROO' 'YUCATAN' 'GUANAJUATO' 'QUERETARO' 'CAMPECHE' 'HIDALGO'
#  'PUEBLA' 'MICHOACAN' 'MEXICO' 'TLAXCALA' 'CIUDAD DE MEXICO' 'COLIMA'
#  'MORELOS' 'TABASCO' 'GUERRERO' 'OAXACA' 'CHIAPAS']
# Entidades en el CSV después de normalizar:
# ['AGUASCALIENTES' 'BAJA CALIFORNIA' 'BAJA CALIFORNIA SUR' 'CAMPECHE'
#  'CHIAPAS' 'CHIHUAHUA' 'CIUDAD DE MEXICO' 'COAHUILA' 'COLIMA' 'DURANGO'
#  'GUANAJUATO' 'GUERRERO' 'HIDALGO' 'JALISCO' 'MEXICO' 'MICHOACAN'
#  'MORELOS' 'NAYARIT' 'NUEVO LEON' 'OAXACA' 'PUEBLA' 'QUERETARO'
#  'QUINTANA ROO' 'SAN LUIS POTOSI' 'SINALOA' 'SONORA' 'TABASCO'
#  'TAMAULIPAS' 'TLAXCALA' 'VERACRUZ' 'YUCATAN' 'ZACATECAS']
#            ENTIDAD    color
# 0  BAJA CALIFORNIA  #8B4513
# ...

# %%
import geopandas as gpd
import pandas as pd
from unidecode import unidecode
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# Cargar el shapefile de México
mexico_shapefile_path = './dest_2010gw/dest_2010gw.shp'
mexico = gpd.read_file(mexico_shapefile_path)

# Normalizar y mapear los nombres de las entidades en el shapefile
entity_mapping = {
    'BAJA CALIFORNIA': 'BAJA CALIFORNIA',
    'SONORA': 'SONORA',
    'CHIHUAHUA': 'CHIHUAHUA',
    'COAHUILA DE ZARAGOZA': 'COAHUILA',
    'BAJA CALIFORNIA SUR': 'BAJA CALIFORNIA SUR',
    'NUEVO LEON': 'NUEVO LEON',
    'TAMAULIPAS': 'TAMAULIPAS',
    'SINALOA': 'SINALOA',
    'DURANGO': 'DURANGO',
    'ZACATECAS': 'ZACATECAS',
    'SAN LUIS POTOSI': 'SAN LUIS POTOSI',
    'NAYARIT': 'NAYARIT',
    'JALISCO': 'JALISCO',
    'VERACRUZ DE IGNACIO DE LA LLAVE': 'VERACRUZ',
    'AGUASCALIENTES': 'AGUASCALIENTES',
    'QUINTANA ROO': 'QUINTANA ROO',
    'YUCATAN': 'YUCATAN',
    'GUANAJUATO': 'GUANAJUATO',
    'QUERETARO DE ARTEAGA': 'QUERETARO',
    'CAMPECHE': 'CAMPECHE',
    'HIDALGO': 'HIDALGO',
    'PUEBLA': 'PUEBLA',
    'MICHOACAN DE OCAMPO': 'MICHOACAN',
    'MEXICO': 'MEXICO',
    'TLAXCALA': 'TLAXCALA',
    'DISTRITO FEDERAL': 'CIUDAD DE MEXICO',
    'COLIMA': 'COLIMA',
    'MORELOS': 'MORELOS',
    'TABASCO': 'TABASCO',
    'GUERRERO': 'GUERRERO',
    'OAXACA': 'OAXACA',
    'CHIAPAS': 'CHIAPAS'
}
mexico['ENTIDAD'] = mexico['ENTIDAD'].apply(unidecode).str.upper().replace(entity_mapping)

# Cargar los datos de votos
file_path = 'ELECTIONS_vs_SOCIODEMOGRAPHICS_ALT2.csv'
data = pd.read_csv(file_path)

# Normalizar los nombres de las entidades en el CSV
data['ENTIDAD'] = data['ENTIDAD'].apply(unidecode).str.upper()

# Crear una columna para el ganador en cada estado
data['Winner'] = data[['COMPETITOR_Votes_2024', 'Xochitl_Opposition_Votes', 'Maynez_Independant_Votes']].idxmax(axis=1)

# Mapping winners to colors using hex color codes
color_mapping = {
    'COMPETITOR_Votes_2024': '#8B4513',  # Claudia Sheinbaum - Brown
    'Xochitl_Opposition_Votes': '#0000FF',  # Xochitl Galvez - Blue
    'Maynez_Independant_Votes': '#FFA500'  # Maynez - Orange
}
data['color'] = data['Winner'].map(color_mapping)

# Unir los datos con el shapefile de México
mexico = mexico.merge(data, on='ENTIDAD', how='left')

# Verificar la unión y los colores
print(mexico[['ENTIDAD', 'Winner', 'color']].head(32))

# Crear el gráfico
fig, ax = plt.subplots(1, 1, figsize=(15, 15))
mexico.boundary.plot(ax=ax, linewidth=1)
mexico.plot(column='color', ax=ax, legend=False, categorical=True, edgecolor='black')

# Personalizar la leyenda
legend_patches = [
    mpatches.Patch(color='#8B4513', label='Claudia Sheinbaum'),
    mpatches.Patch(color='#0000FF', label='Xochitl Galvez'),
    mpatches.Patch(color='#FFA500', label='Maynez')
]

ax.legend(handles=legend_patches, loc='lower left')

# Eliminar los ejes
ax.set_axis_off()

plt.show()
# Out:
#             ENTIDAD                 Winner    color
# 0   BAJA CALIFORNIA  COMPETITOR_Votes_2024  #8B4513
# 1   BAJA CALIFORNIA  COMPETITOR_Votes_2024  #8B4513
# 2   BAJA CALIFORNIA  COMPETITOR_Votes_2024  #8B4513
# 3   BAJA CALIFORNIA  COMPETITOR_Votes_2024  #8B4513
# 4   BAJA CALIFORNIA  COMPETITOR_Votes_2024  #8B4513
# 5            SONORA  COMPETITOR_Votes_2024  #8B4513
# 6   BAJA CALIFORNIA  COMPETITOR_Votes_2024  #8B4513
# 7   BAJA CALIFORNIA  COMPETITOR_Votes_2024  #8B4513
# 8         CHIHUAHUA  COMPETITOR_Votes_2024  #8B4513
# 9   BAJA CALIFORNIA  COMPETITOR_Votes_2024  #8B4513
# 10  BAJA CALIFORNIA  COMPETITOR_Votes_2024  #8B4513
# 11  BAJA CALIFORNIA  COMPETITOR_Votes_2024  #8B4513
# 12  BAJA CALIFORNIA  COMPETITOR_Votes_2024  #8B4513
# 13  BAJA CALIFORNIA  COMPETITOR_Votes_2024  #8B4513
# 14  BAJA CALIFORNIA  COMPETITOR_Votes_2024  #8B4513
# 15  BAJA CALIFORNIA  COMPETITOR_Votes_2024  #8B4513
# 16  BAJA CALIFORNIA  COMPETITOR_Votes_2024  #8B4513
# ...

# %%
import geopandas as gpd
import pandas as pd
from unidecode import unidecode
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# Cargar el shapefile de México
mexico_shapefile_path = './dest_2010gw/dest_2010gw.shp'
mexico = gpd.read_file(mexico_shapefile_path)

# Normalizar y mapear los nombres de las entidades en el shapefile
entity_mapping = {
    'BAJA CALIFORNIA': 'BAJA CALIFORNIA',
    'SONORA': 'SONORA',
    'CHIHUAHUA': 'CHIHUAHUA',
    'COAHUILA DE ZARAGOZA': 'COAHUILA',
    'BAJA CALIFORNIA SUR': 'BAJA CALIFORNIA SUR',
    'NUEVO LEON': 'NUEVO LEON',
    'TAMAULIPAS': 'TAMAULIPAS',
    'SINALOA': 'SINALOA',
    'DURANGO': 'DURANGO',
    'ZACATECAS': 'ZACATECAS',
    'SAN LUIS POTOSI': 'SAN LUIS POTOSI',
    'NAYARIT': 'NAYARIT',
    'JALISCO': 'JALISCO',
    'VERACRUZ DE IGNACIO DE LA LLAVE': 'VERACRUZ',
    'AGUASCALIENTES': 'AGUASCALIENTES',
    'QUINTANA ROO': 'QUINTANA ROO',
    'YUCATAN': 'YUCATAN',
    'GUANAJUATO': 'GUANAJUATO',
    'QUERETARO DE ARTEAGA': 'QUERETARO',
    'CAMPECHE': 'CAMPECHE',
    'HIDALGO': 'HIDALGO',
    'PUEBLA': 'PUEBLA',
    'MICHOACAN DE OCAMPO': 'MICHOACAN',
    'MEXICO': 'MEXICO',
    'TLAXCALA': 'TLAXCALA',
    'DISTRITO FEDERAL': 'CIUDAD DE MEXICO',
    'COLIMA': 'COLIMA',
    'MORELOS': 'MORELOS',
    'TABASCO': 'TABASCO',
    'GUERRERO': 'GUERRERO',
    'OAXACA': 'OAXACA',
    'CHIAPAS': 'CHIAPAS'
}
mexico['ENTIDAD'] = mexico['ENTIDAD'].apply(unidecode).str.upper().replace(entity_mapping)

# Cargar los datos de votos
file_path = 'ELECTIONS_vs_SOCIODEMOGRAPHICS_ALT2.csv'
data = pd.read_csv(file_path)

# Normalizar los nombres de las entidades en el CSV
data['ENTIDAD'] = data['ENTIDAD'].apply(unidecode).str.upper()

# Crear una columna para el ganador en cada estado
data['Winner'] = data[['COMPETITOR_Votes_2024', 'Xochitl_Opposition_Votes', 'Maynez_Independant_Votes']].idxmax(axis=1)

# Mapping winners to colors using hex color codes
color_mapping = {
    'COMPETITOR_Votes_2024': '#8B4513',  # Claudia Sheinbaum - Brown
    'Xochitl_Opposition_Votes': '#0000FF',  # Xochitl Galvez - Blue
    'Maynez_Independant_Votes': '#FFA500'  # Maynez - Orange
}
data['color'] = data['Winner'].map(color_mapping)

# Verificar los datos antes de la unión
print("Datos de votos con colores asignados:")
print(data[['ENTIDAD', 'Winner', 'color']])

# Unir los datos con el shapefile de México
mexico = mexico.merge(data, on='ENTIDAD', how='left')

# Verificar la unión y los colores después de la unión
print("Datos combinados después de la unión:")
print(mexico[['ENTIDAD', 'Winner', 'color']])

# Crear el gráfico
fig, ax = plt.subplots(1, 1, figsize=(15, 15))
mexico.boundary.plot(ax=ax, linewidth=1)
mexico.plot(column='color', ax=ax, legend=False, categorical=True, edgecolor='black')

# Personalizar la leyenda
legend_patches = [
    mpatches.Patch(color='#8B4513', label='Claudia Sheinbaum'),
    mpatches.Patch(color='#0000FF', label='Xochitl Galvez'),
    mpatches.Patch(color='#FFA500', label='Maynez')
]

ax.legend(handles=legend_patches, loc='lower left')

# Eliminar los ejes
ax.set_axis_off()

plt.show()
# Out:
# Datos de votos con colores asignados:
#                 ENTIDAD                    Winner    color
# 0        AGUASCALIENTES  Xochitl_Opposition_Votes  #0000FF
# 1       BAJA CALIFORNIA     COMPETITOR_Votes_2024  #8B4513
# 2   BAJA CALIFORNIA SUR     COMPETITOR_Votes_2024  #8B4513
# 3              CAMPECHE     COMPETITOR_Votes_2024  #8B4513
# 4               CHIAPAS     COMPETITOR_Votes_2024  #8B4513
# 5             CHIHUAHUA     COMPETITOR_Votes_2024  #8B4513
# 6      CIUDAD DE MEXICO     COMPETITOR_Votes_2024  #8B4513
# 7              COAHUILA     COMPETITOR_Votes_2024  #8B4513
# 8                COLIMA     COMPETITOR_Votes_2024  #8B4513
# 9               DURANGO     COMPETITOR_Votes_2024  #8B4513
# 10           GUANAJUATO     COMPETITOR_Votes_2024  #8B4513
# 11             GUERRERO     COMPETITOR_Votes_2024  #8B4513
# 12              HIDALGO     COMPETITOR_Votes_2024  #8B4513
# 13              JALISCO     COMPETITOR_Votes_2024  #8B4513
# ...

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import random

# Cargar el shapefile de México
mexico_shapefile_path = './dest_2010gw/dest_2010gw.shp'
mexico = gpd.read_file(mexico_shapefile_path)

# Generar una lista de colores
colors = plt.cm.get_cmap('tab20', len(mexico))  # Utilizamos el colormap 'tab20' que tiene 20 colores diferentes

# Asignar un color diferente a cada estado
mexico['color'] = [colors(i) for i in range(len(mexico))]

# Crear el gráfico
fig, ax = plt.subplots(1, 1, figsize=(15, 15))
mexico.boundary.plot(ax=ax, linewidth=1)
mexico.plot(column='color', ax=ax, legend=False, edgecolor='black')

# Eliminar los ejes
ax.set_axis_off()

plt.show()
# Out:
# /tmp/ipykernel_7201/3460169718.py:10: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap('tab20', len(mexico))  # Utilizamos el colormap 'tab20' que tiene 20 colores diferentes

# %%
import geopandas as gpd
import pandas as pd
from unidecode import unidecode
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# Cargar el shapefile de México
mexico_shapefile_path = './dest_2010gw/dest_2010gw.shp'
mexico = gpd.read_file(mexico_shapefile_path)

# Normalizar y mapear los nombres de las entidades en el shapefile
entity_mapping = {
    'BAJA CALIFORNIA': 'BAJA CALIFORNIA',
    'SONORA': 'SONORA',
    'CHIHUAHUA': 'CHIHUAHUA',
    'COAHUILA DE ZARAGOZA': 'COAHUILA',
    'BAJA CALIFORNIA SUR': 'BAJA CALIFORNIA SUR',
    'NUEVO LEON': 'NUEVO LEON',
    'TAMAULIPAS': 'TAMAULIPAS',
    'SINALOA': 'SINALOA',
    'DURANGO': 'DURANGO',
    'ZACATECAS': 'ZACATECAS',
    'SAN LUIS POTOSI': 'SAN LUIS POTOSI',
    'NAYARIT': 'NAYARIT',
    'JALISCO': 'JALISCO',
    'VERACRUZ DE IGNACIO DE LA LLAVE': 'VERACRUZ',
    'AGUASCALIENTES': 'AGUASCALIENTES',
    'QUINTANA ROO': 'QUINTANA ROO',
    'YUCATAN': 'YUCATAN',
    'GUANAJUATO': 'GUANAJUATO',
    'QUERETARO DE ARTEAGA': 'QUERETARO',
    'CAMPECHE': 'CAMPECHE',
    'HIDALGO': 'HIDALGO',
    'PUEBLA': 'PUEBLA',
    'MICHOACAN DE OCAMPO': 'MICHOACAN',
    'MEXICO': 'MEXICO',
    'TLAXCALA': 'TLAXCALA',
    'DISTRITO FEDERAL': 'CIUDAD DE MEXICO',
    'COLIMA': 'COLIMA',
    'MORELOS': 'MORELOS',
    'TABASCO': 'TABASCO',
    'GUERRERO': 'GUERRERO',
    'OAXACA': 'OAXACA',
    'CHIAPAS': 'CHIAPAS'
}
mexico['ENTIDAD'] = mexico['ENTIDAD'].apply(unidecode).str.upper().replace(entity_mapping)

# Cargar los datos de votos
file_path = 'ELECTIONS_vs_SOCIODEMOGRAPHICS_ALT2.csv'
data = pd.read_csv(file_path)

# Normalizar los nombres de las entidades en el CSV
data['ENTIDAD'] = data['ENTIDAD'].apply(unidecode).str.upper()

# Crear una columna para el ganador en cada estado
data['Winner'] = data[['COMPETITOR_Votes_2024', 'Xochitl_Opposition_Votes', 'Maynez_Independant_Votes']].idxmax(axis=1)

# Mapping winners to colors using hex color codes from tab10 colormap
color_mapping = {
    'COMPETITOR_Votes_2024': '#1f77b4',  # Claudia Sheinbaum - Blue
    'Xochitl_Opposition_Votes': '#ff7f0e',  # Xochitl Galvez - Orange
    'Maynez_Independant_Votes': '#2ca02c'  # Maynez - Green
}
data['color'] = data['Winner'].map(color_mapping)

# Verificar los datos antes de la unión
print("Datos de votos con colores asignados:")
print(data[['ENTIDAD', 'Winner', 'color']])

# Verificar los datos del shapefile de México
print("Datos del shapefile de México:")
print(mexico[['ENTIDAD']].head())

# Unir los datos con el shapefile de México
mexico = mexico.merge(data, on='ENTIDAD', how='left')

# Verificar la unión y los colores después de la unión
print("Datos combinados después de la unión:")
print(mexico[['ENTIDAD', 'Winner', 'color']].head(32))

# Crear el gráfico simplificado
fig, ax = plt.subplots(1, 1, figsize=(15, 15))
mexico.boundary.plot(ax=ax, linewidth=1)
mexico.plot(column='color', ax=ax, legend=False, edgecolor='black')

# Personalizar la leyenda
legend_patches = [
    mpatches.Patch(color='#1f77b4', label='Claudia Sheinbaum'),
    mpatches.Patch(color='#ff7f0e', label='Xochitl Galvez'),
    mpatches.Patch(color='#2ca02c', label='Maynez')
]

ax.legend(handles=legend_patches, loc='lower left')

# Eliminar los ejes
ax.set_axis_off()

plt.show()
# Out:
# Datos de votos con colores asignados:
#                 ENTIDAD                    Winner    color
# 0        AGUASCALIENTES  Xochitl_Opposition_Votes  #ff7f0e
# 1       BAJA CALIFORNIA     COMPETITOR_Votes_2024  #1f77b4
# 2   BAJA CALIFORNIA SUR     COMPETITOR_Votes_2024  #1f77b4
# 3              CAMPECHE     COMPETITOR_Votes_2024  #1f77b4
# 4               CHIAPAS     COMPETITOR_Votes_2024  #1f77b4
# 5             CHIHUAHUA     COMPETITOR_Votes_2024  #1f77b4
# 6      CIUDAD DE MEXICO     COMPETITOR_Votes_2024  #1f77b4
# 7              COAHUILA     COMPETITOR_Votes_2024  #1f77b4
# 8                COLIMA     COMPETITOR_Votes_2024  #1f77b4
# 9               DURANGO     COMPETITOR_Votes_2024  #1f77b4
# 10           GUANAJUATO     COMPETITOR_Votes_2024  #1f77b4
# 11             GUERRERO     COMPETITOR_Votes_2024  #1f77b4
# 12              HIDALGO     COMPETITOR_Votes_2024  #1f77b4
# 13              JALISCO     COMPETITOR_Votes_2024  #1f77b4
# ...

# %%
import geopandas as gpd
import pandas as pd
from unidecode import unidecode
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# Cargar el shapefile de México
mexico_shapefile_path = './dest_2010gw/dest_2010gw.shp'
mexico = gpd.read_file(mexico_shapefile_path)

# Normalizar y mapear los nombres de las entidades en el shapefile
entity_mapping = {
    'BAJA CALIFORNIA': 'BAJA CALIFORNIA',
    'SONORA': 'SONORA',
    'CHIHUAHUA': 'CHIHUAHUA',
    'COAHUILA DE ZARAGOZA': 'COAHUILA',
    'BAJA CALIFORNIA SUR': 'BAJA CALIFORNIA SUR',
    'NUEVO LEON': 'NUEVO LEON',
    'TAMAULIPAS': 'TAMAULIPAS',
    'SINALOA': 'SINALOA',
    'DURANGO': 'DURANGO',
    'ZACATECAS': 'ZACATECAS',
    'SAN LUIS POTOSI': 'SAN LUIS POTOSI',
    'NAYARIT': 'NAYARIT',
    'JALISCO': 'JALISCO',
    'VERACRUZ DE IGNACIO DE LA LLAVE': 'VERACRUZ',
    'AGUASCALIENTES': 'AGUASCALIENTES',
    'QUINTANA ROO': 'QUINTANA ROO',
    'YUCATAN': 'YUCATAN',
    'GUANAJUATO': 'GUANAJUATO',
    'QUERETARO DE ARTEAGA': 'QUERETARO',
    'CAMPECHE': 'CAMPECHE',
    'HIDALGO': 'HIDALGO',
    'PUEBLA': 'PUEBLA',
    'MICHOACAN DE OCAMPO': 'MICHOACAN',
    'MEXICO': 'MEXICO',
    'TLAXCALA': 'TLAXCALA',
    'DISTRITO FEDERAL': 'CIUDAD DE MEXICO',
    'COLIMA': 'COLIMA',
    'MORELOS': 'MORELOS',
    'TABASCO': 'TABASCO',
    'GUERRERO': 'GUERRERO',
    'OAXACA': 'OAXACA',
    'CHIAPAS': 'CHIAPAS'
}
mexico['ENTIDAD'] = mexico['ENTIDAD'].apply(unidecode).str.upper().replace(entity_mapping)

# Cargar los datos de votos
file_path = 'ELECTIONS_vs_SOCIODEMOGRAPHICS_ALT2.csv'
data = pd.read_csv(file_path)

# Normalizar los nombres de las entidades en el CSV
data['ENTIDAD'] = data['ENTIDAD'].apply(unidecode).str.upper()

# Crear una columna para el ganador en cada estado
data['Claudia_Votes'] = data['COMPETITOR_Votes_2024']
data['Xochitl_Votes'] = data['Xochitl_Opposition_Votes']

# Crear condiciones para asignar colores
def assign_color(row):
    if row['Claudia_Votes'] >= 2 * row['Xochitl_Votes']:
        return 'red'  # Claudia superó a Xochitl por el doble o más
    elif row['Claudia_Votes'] > row['Xochitl_Votes']:
        return 'yellow'  # Claudia superó a Xochitl por menos del doble
    else:
        return 'green'  # Xochitl ganó

data['color'] = data.apply(assign_color, axis=1)

# Verificar los datos antes de la unión
print("Datos de votos con colores asignados:")
print(data[['ENTIDAD', 'Claudia_Votes', 'Xochitl_Votes', 'color']])

# Unir los datos con el shapefile de México
mexico = mexico.merge(data[['ENTIDAD', 'color']], on='ENTIDAD', how='left')

# Verificar la unión y los colores después de la unión
print("Datos combinados después de la unión:")
print(mexico[['ENTIDAD', 'color']].head(32))

# Crear el gráfico simplificado
fig, ax = plt.subplots(1, 1, figsize=(15, 15))
mexico.boundary.plot(ax=ax, linewidth=1)
mexico.plot(column='color', ax=ax, legend=False, edgecolor='black')

# Personalizar la leyenda
legend_patches = [
    mpatches.Patch(color='red', label='Claudia superó a Xochitl por el doble o más'),
    mpatches.Patch(color='yellow', label='Claudia superó a Xochitl por menos del doble'),
    mpatches.Patch(color='green', label='Xochitl ganó')
]

ax.legend(handles=legend_patches, loc='lower left')

# Eliminar los ejes
ax.set_axis_off()

plt.show()
# Out:
# Datos de votos con colores asignados:
#                 ENTIDAD  Claudia_Votes  Xochitl_Votes   color
# 0        AGUASCALIENTES         270389         294746   green
# 1       BAJA CALIFORNIA         862661         290698     red
# 2   BAJA CALIFORNIA SUR         175755          90838  yellow
# 3              CAMPECHE         240693          62268     red
# 4               CHIAPAS        1519559         355592     red
# 5             CHIHUAHUA         744823         495324  yellow
# 6      CIUDAD DE MEXICO        2978243        1862780  yellow
# 7              COAHUILA         813432         595270  yellow
# 8                COLIMA         182063         102288  yellow
# 9               DURANGO         402566         227617  yellow
# 10           GUANAJUATO        1223770        1057455  yellow
# 11             GUERRERO        1039283         276953     red
# 12              HIDALGO        1001963         299831     red
# 13              JALISCO        1592942        1303587  yellow
# ...

# %%
import geopandas as gpd
import pandas as pd
from unidecode import unidecode
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# Cargar el shapefile de México
mexico_shapefile_path = './dest_2010gw/dest_2010gw.shp'
mexico = gpd.read_file(mexico_shapefile_path)

# Normalizar y mapear los nombres de las entidades en el shapefile
entity_mapping = {
    'BAJA CALIFORNIA': 'BAJA CALIFORNIA',
    'SONORA': 'SONORA',
    'CHIHUAHUA': 'CHIHUAHUA',
    'COAHUILA DE ZARAGOZA': 'COAHUILA',
    'BAJA CALIFORNIA SUR': 'BAJA CALIFORNIA SUR',
    'NUEVO LEON': 'NUEVO LEON',
    'TAMAULIPAS': 'TAMAULIPAS',
    'SINALOA': 'SINALOA',
    'DURANGO': 'DURANGO',
    'ZACATECAS': 'ZACATECAS',
    'SAN LUIS POTOSI': 'SAN LUIS POTOSI',
    'NAYARIT': 'NAYARIT',
    'JALISCO': 'JALISCO',
    'VERACRUZ DE IGNACIO DE LA LLAVE': 'VERACRUZ',
    'AGUASCALIENTES': 'AGUASCALIENTES',
    'QUINTANA ROO': 'QUINTANA ROO',
    'YUCATAN': 'YUCATAN',
    'GUANAJUATO': 'GUANAJUATO',
    'QUERETARO DE ARTEAGA': 'QUERETARO',
    'CAMPECHE': 'CAMPECHE',
    'HIDALGO': 'HIDALGO',
    'PUEBLA': 'PUEBLA',
    'MICHOACAN DE OCAMPO': 'MICHOACAN',
    'MEXICO': 'MEXICO',
    'TLAXCALA': 'TLAXCALA',
    'DISTRITO FEDERAL': 'CIUDAD DE MEXICO',
    'COLIMA': 'COLIMA',
    'MORELOS': 'MORELOS',
    'TABASCO': 'TABASCO',
    'GUERRERO': 'GUERRERO',
    'OAXACA': 'OAXACA',
    'CHIAPAS': 'CHIAPAS'
}
mexico['ENTIDAD'] = mexico['ENTIDAD'].apply(unidecode).str.upper().replace(entity_mapping)

# Cargar los datos de votos
file_path = 'ELECTIONS_vs_SOCIODEMOGRAPHICS_ALT2.csv'
data = pd.read_csv(file_path)

# Normalizar los nombres de las entidades en el CSV
data['ENTIDAD'] = data['ENTIDAD'].apply(unidecode).str.upper()

# Crear una columna para el ganador en cada estado
data['Claudia_Votes'] = data['COMPETITOR_Votes_2024']
data['Xochitl_Votes'] = data['Xochitl_Opposition_Votes']

# Crear condiciones para asignar colores
def assign_color(row):
    if row['Claudia_Votes'] >= 2 * row['Xochitl_Votes']:
        return 'red'  # Claudia superó a Xochitl por el doble o más
    elif row['Claudia_Votes'] > row['Xochitl_Votes']:
        return 'yellow'  # Claudia superó a Xochitl por menos del doble
    else:
        return 'green'  # Xochitl ganó

data['color'] = data.apply(assign_color, axis=1)

# Verificar los datos antes de la unión
print("Datos de votos con colores asignados:")
print(data[['ENTIDAD', 'Claudia_Votes', 'Xochitl_Votes', 'color']])

# Unir los datos con el shapefile de México
mexico = mexico.merge(data[['ENTIDAD', 'color']], on='ENTIDAD', how='left')

# Verificar la unión y los colores después de la unión
print("Datos combinados después de la unión:")
print(mexico[['ENTIDAD', 'color']].head(32))

# Crear el gráfico simplificado
fig, ax = plt.subplots(1, 1, figsize=(15, 15))
mexico.boundary.plot(ax=ax, linewidth=1)
mexico.plot(column='color', ax=ax, legend=False, edgecolor='black')

# Personalizar la leyenda
legend_patches = [
    mpatches.Patch(color='red', label='Claudia superó a Xochitl por el doble o más'),
    mpatches.Patch(color='yellow', label='Claudia superó a Xochitl por menos del doble'),
    mpatches.Patch(color='green', label='Xochitl ganó')
]

ax.legend(handles=legend_patches, loc='lower left')

# Eliminar los ejes
ax.set_axis_off()

plt.show()
# Out:
# Datos de votos con colores asignados:
#                 ENTIDAD  Claudia_Votes  Xochitl_Votes   color
# 0        AGUASCALIENTES         270389         294746   green
# 1       BAJA CALIFORNIA         862661         290698     red
# 2   BAJA CALIFORNIA SUR         175755          90838  yellow
# 3              CAMPECHE         240693          62268     red
# 4               CHIAPAS        1519559         355592     red
# 5             CHIHUAHUA         744823         495324  yellow
# 6      CIUDAD DE MEXICO        2978243        1862780  yellow
# 7              COAHUILA         813432         595270  yellow
# 8                COLIMA         182063         102288  yellow
# 9               DURANGO         402566         227617  yellow
# 10           GUANAJUATO        1223770        1057455  yellow
# 11             GUERRERO        1039283         276953     red
# 12              HIDALGO        1001963         299831     red
# 13              JALISCO        1592942        1303587  yellow
# ...

# %%
import geopandas as gpd
import pandas as pd
from unidecode import unidecode
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# Cargar el shapefile de México
mexico_shapefile_path = './dest_2010gw/dest_2010gw.shp'
mexico = gpd.read_file(mexico_shapefile_path)

# Normalizar y mapear los nombres de las entidades en el shapefile
entity_mapping = {
    'BAJA CALIFORNIA': 'BAJA CALIFORNIA',
    'SONORA': 'SONORA',
    'CHIHUAHUA': 'CHIHUAHUA',
    'COAHUILA DE ZARAGOZA': 'COAHUILA',
    'BAJA CALIFORNIA SUR': 'BAJA CALIFORNIA SUR',
    'NUEVO LEON': 'NUEVO LEON',
    'TAMAULIPAS': 'TAMAULIPAS',
    'SINALOA': 'SINALOA',
    'DURANGO': 'DURANGO',
    'ZACATECAS': 'ZACATECAS',
    'SAN LUIS POTOSI': 'SAN LUIS POTOSI',
    'NAYARIT': 'NAYARIT',
    'JALISCO': 'JALISCO',
    'VERACRUZ DE IGNACIO DE LA LLAVE': 'VERACRUZ',
    'AGUASCALIENTES': 'AGUASCALIENTES',
    'QUINTANA ROO': 'QUINTANA ROO',
    'YUCATAN': 'YUCATAN',
    'GUANAJUATO': 'GUANAJUATO',
    'QUERETARO DE ARTEAGA': 'QUERETARO',
    'CAMPECHE': 'CAMPECHE',
    'HIDALGO': 'HIDALGO',
    'PUEBLA': 'PUEBLA',
    'MICHOACAN DE OCAMPO': 'MICHOACAN',
    'MEXICO': 'MEXICO',
    'TLAXCALA': 'TLAXCALA',
    'DISTRITO FEDERAL': 'CIUDAD DE MEXICO',
    'COLIMA': 'COLIMA',
    'MORELOS': 'MORELOS',
    'TABASCO': 'TABASCO',
    'GUERRERO': 'GUERRERO',
    'OAXACA': 'OAXACA',
    'CHIAPAS': 'CHIAPAS'
}
mexico['ENTIDAD'] = mexico['ENTIDAD'].apply(unidecode).str.upper().replace(entity_mapping)

# Cargar los datos de votos
file_path = 'ELECTIONS_vs_SOCIODEMOGRAPHICS_ALT2.csv'
data = pd.read_csv(file_path)

# Normalizar los nombres de las entidades en el CSV
data['ENTIDAD'] = data['ENTIDAD'].apply(unidecode).str.upper()

# Crear una columna para el ganador en cada estado
data['Claudia_Votes'] = data['COMPETITOR_Votes_2024']
data['Xochitl_Votes'] = data['Xochitl_Opposition_Votes']

# Crear condiciones para asignar colores
def assign_color(row):
    if row['Claudia_Votes'] >= 2 * row['Xochitl_Votes']:
        return 'red'  # Claudia superó a Xochitl por el doble o más
    elif row['Claudia_Votes'] > row['Xochitl_Votes']:
        return 'yellow'  # Claudia superó a Xochitl por menos del doble
    else:
        return 'green'  # Xochitl ganó

data['color'] = data.apply(assign_color, axis=1)

# Verificar los datos antes de la unión
print("Datos de votos con colores asignados:")
print(data[['ENTIDAD', 'Claudia_Votes', 'Xochitl_Votes', 'color']])

# Unir los datos con el shapefile de México
mexico = mexico.merge(data[['ENTIDAD', 'color']], on='ENTIDAD', how='left')

# Verificar la unión y los colores después de la unión
print("Datos combinados después de la unión:")
print(mexico[['ENTIDAD', 'color']].head(32))

# Crear el gráfico simplificado
fig, ax = plt.subplots(1, 1, figsize=(15, 15))
mexico.boundary.plot(ax=ax, linewidth=1)
mexico.plot(column='color', ax=ax, legend=False, edgecolor='black')

# Personalizar la leyenda
legend_patches = [
    mpatches.Patch(color='red', label='Claudia superó a Xochitl por el doble o más'),
    mpatches.Patch(color='yellow', label='Claudia superó a Xochitl por menos del doble'),
    mpatches.Patch(color='green', label='Xochitl ganó')
]

ax.legend(handles=legend_patches, loc='lower left')

# Eliminar los ejes
ax.set_axis_off()

plt.show()
# Out:
# Datos de votos con colores asignados:
#                 ENTIDAD  Claudia_Votes  Xochitl_Votes   color
# 0        AGUASCALIENTES         270389         294746   green
# 1       BAJA CALIFORNIA         862661         290698     red
# 2   BAJA CALIFORNIA SUR         175755          90838  yellow
# 3              CAMPECHE         240693          62268     red
# 4               CHIAPAS        1519559         355592     red
# 5             CHIHUAHUA         744823         495324  yellow
# 6      CIUDAD DE MEXICO        2978243        1862780  yellow
# 7              COAHUILA         813432         595270  yellow
# 8                COLIMA         182063         102288  yellow
# 9               DURANGO         402566         227617  yellow
# 10           GUANAJUATO        1223770        1057455  yellow
# 11             GUERRERO        1039283         276953     red
# 12              HIDALGO        1001963         299831     red
# 13              JALISCO        1592942        1303587  yellow
# ...

# %%
import pandas as pd

# Cargar el subconjunto del archivo CSV
file_path = 'subconjunto.csv'
sub_data = pd.read_csv(file_path)

# Normalizar los nombres de las entidades en el subconjunto
sub_data['ENTIDAD'] = sub_data['ENTIDAD'].apply(unidecode).str.upper()

# Crear una columna para el ganador en cada estado
sub_data['Claudia_Votes'] = sub_data['COMPETITOR_Votes_2024']
sub_data['Xochitl_Votes'] = sub_data['Xochitl_Opposition_Votes']

# Crear condiciones para asignar colores
def assign_color(row):
    if row['Claudia_Votes'] >= 2 * row['Xochitl_Votes']:
        return 'red'  # Claudia superó a Xochitl por el doble o más
    elif row['Claudia_Votes'] > row['Xochitl_Votes']:
        return 'yellow'  # Claudia superó a Xochitl por menos del doble
    else:
        return 'green'  # Xochitl ganó

sub_data['color'] = sub_data.apply(assign_color, axis=1)

# Verificar los datos del subconjunto con los colores asignados
print("Datos del subconjunto con colores asignados:")
print(sub_data[['ENTIDAD', 'Claudia_Votes', 'Xochitl_Votes', 'color']])
# Out:
# Datos del subconjunto con colores asignados:
#                ENTIDAD  Claudia_Votes  Xochitl_Votes   color
# 0       AGUASCALIENTES         270389         294746   green
# 1      BAJA CALIFORNIA         862661         290698     red
# 2  BAJA CALIFORNIA SUR         175755          90838  yellow
# 3             CAMPECHE         240693          62268     red
# 4              CHIAPAS        1519559         355592     red
# 5            CHIHUAHUA         744823         495324  yellow
# 6     CIUDAD DE MEXICO        2978243        1862780  yellow
# 7             COAHUILA         813432         595270  yellow
# 8               COLIMA         182063         102288  yellow
# 9              DURANGO         402566         227617  yellow

# %%
import geopandas as gpd
import pandas as pd
from unidecode import unidecode
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# Cargar el shapefile de México
mexico_shapefile_path = './dest_2010gw/dest_2010gw.shp'
mexico = gpd.read_file(mexico_shapefile_path)

# Normalizar y mapear los nombres de las entidades en el shapefile
entity_mapping = {
    'BAJA CALIFORNIA': 'BAJA CALIFORNIA',
    'SONORA': 'SONORA',
    'CHIHUAHUA': 'CHIHUAHUA',
    'COAHUILA DE ZARAGOZA': 'COAHUILA',
    'BAJA CALIFORNIA SUR': 'BAJA CALIFORNIA SUR',
    'NUEVO LEON': 'NUEVO LEON',
    'TAMAULIPAS': 'TAMAULIPAS',
    'SINALOA': 'SINALOA',
    'DURANGO': 'DURANGO',
    'ZACATECAS': 'ZACATECAS',
    'SAN LUIS POTOSI': 'SAN LUIS POTOSI',
    'NAYARIT': 'NAYARIT',
    'JALISCO': 'JALISCO',
    'VERACRUZ DE IGNACIO DE LA LLAVE': 'VERACRUZ',
    'AGUASCALIENTES': 'AGUASCALIENTES',
    'QUINTANA ROO': 'QUINTANA ROO',
    'YUCATAN': 'YUCATAN',
    'GUANAJUATO': 'GUANAJUATO',
    'QUERETARO DE ARTEAGA': 'QUERETARO',
    'CAMPECHE': 'CAMPECHE',
    'HIDALGO': 'HIDALGO',
    'PUEBLA': 'PUEBLA',
    'MICHOACAN DE OCAMPO': 'MICHOACAN',
    'MEXICO': 'MEXICO',
    'TLAXCALA': 'TLAXCALA',
    'DISTRITO FEDERAL': 'CIUDAD DE MEXICO',
    'COLIMA': 'COLIMA',
    'MORELOS': 'MORELOS',
    'TABASCO': 'TABASCO',
    'GUERRERO': 'GUERRERO',
    'OAXACA': 'OAXACA',
    'CHIAPAS': 'CHIAPAS'
}
mexico['ENTIDAD'] = mexico['ENTIDAD'].apply(unidecode).str.upper().replace(entity_mapping)

# Cargar los datos del subconjunto de votos
file_path = 'subconjunto.csv'
sub_data = pd.read_csv(file_path)

# Normalizar los nombres de las entidades en el subconjunto
sub_data['ENTIDAD'] = sub_data['ENTIDAD'].apply(unidecode).str.upper()

# Crear una columna para el ganador en cada estado
sub_data['Claudia_Votes'] = sub_data['COMPETITOR_Votes_2024']
sub_data['Xochitl_Votes'] = sub_data['Xochitl_Opposition_Votes']

# Crear condiciones para asignar colores
def assign_color(row):
    if row['Claudia_Votes'] >= 2 * row['Xochitl_Votes']:
        return 'red'  # Claudia superó a Xochitl por el doble o más
    elif row['Claudia_Votes'] > row['Xochitl_Votes']:
        return 'yellow'  # Claudia superó a Xochitl por menos del doble
    else:
        return 'green'  # Xochitl ganó

sub_data['color'] = sub_data.apply(assign_color, axis=1)

# Verificar los datos del subconjunto con los colores asignados
print("Datos del subconjunto con colores asignados:")
print(sub_data[['ENTIDAD', 'Claudia_Votes', 'Xochitl_Votes', 'color']])

# Unir los datos con el shapefile de México
mexico = mexico.merge(sub_data[['ENTIDAD', 'color']], on='ENTIDAD', how='left')

# Verificar la unión y los colores después de la unión
print("Datos combinados después de la unión:")
print(mexico[['ENTIDAD', 'color']].head(32))

# Crear el gráfico simplificado
fig, ax = plt.subplots(1, 1, figsize=(15, 15))
mexico.boundary.plot(ax=ax, linewidth=1)
mexico.plot(column='color', ax=ax, legend=False, edgecolor='black')

# Personalizar la leyenda
legend_patches = [
    mpatches.Patch(color='red', label='Claudia superó a Xochitl por el doble o más'),
    mpatches.Patch(color='yellow', label='Claudia superó a Xochitl por menos del doble'),
    mpatches.Patch(color='green', label='Xochitl ganó')
]

ax.legend(handles=legend_patches, loc='lower left')

# Eliminar los ejes
ax.set_axis_off()

plt.show()
# Out:
# Datos del subconjunto con colores asignados:
#                ENTIDAD  Claudia_Votes  Xochitl_Votes   color
# 0       AGUASCALIENTES         270389         294746   green
# 1      BAJA CALIFORNIA         862661         290698     red
# 2  BAJA CALIFORNIA SUR         175755          90838  yellow
# 3             CAMPECHE         240693          62268     red
# 4              CHIAPAS        1519559         355592     red
# 5            CHIHUAHUA         744823         495324  yellow
# 6     CIUDAD DE MEXICO        2978243        1862780  yellow
# 7             COAHUILA         813432         595270  yellow
# 8               COLIMA         182063         102288  yellow
# 9              DURANGO         402566         227617  yellow
# Datos combinados después de la unión:
#             ENTIDAD   color
# 0   BAJA CALIFORNIA     red
# 1   BAJA CALIFORNIA     red
# 2   BAJA CALIFORNIA     red
# 3   BAJA CALIFORNIA     red
# 4   BAJA CALIFORNIA     red
# 5            SONORA     NaN
# ...

# %%
import geopandas as gpd
import pandas as pd
from unidecode import unidecode
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# Cargar el shapefile de México
mexico_shapefile_path = './dest_2010gw/dest_2010gw.shp'
mexico = gpd.read_file(mexico_shapefile_path)

# Normalizar y mapear los nombres de las entidades en el shapefile
entity_mapping = {
    'BAJA CALIFORNIA': 'BAJA CALIFORNIA',
    'SONORA': 'SONORA',
    'CHIHUAHUA': 'CHIHUAHUA',
    'COAHUILA DE ZARAGOZA': 'COAHUILA',
    'BAJA CALIFORNIA SUR': 'BAJA CALIFORNIA SUR',
    'NUEVO LEON': 'NUEVO LEON',
    'TAMAULIPAS': 'TAMAULIPAS',
    'SINALOA': 'SINALOA',
    'DURANGO': 'DURANGO',
    'ZACATECAS': 'ZACATECAS',
    'SAN LUIS POTOSI': 'SAN LUIS POTOSI',
    'NAYARIT': 'NAYARIT',
    'JALISCO': 'JALISCO',
    'VERACRUZ DE IGNACIO DE LA LLAVE': 'VERACRUZ',
    'AGUASCALIENTES': 'AGUASCALIENTES',
    'QUINTANA ROO': 'QUINTANA ROO',
    'YUCATAN': 'YUCATAN',
    'GUANAJUATO': 'GUANAJUATO',
    'QUERETARO DE ARTEAGA': 'QUERETARO',
    'CAMPECHE': 'CAMPECHE',
    'HIDALGO': 'HIDALGO',
    'PUEBLA': 'PUEBLA',
    'MICHOACAN DE OCAMPO': 'MICHOACAN',
    'MEXICO': 'MEXICO',
    'TLAXCALA': 'TLAXCALA',
    'DISTRITO FEDERAL': 'CIUDAD DE MEXICO',
    'COLIMA': 'COLIMA',
    'MORELOS': 'MORELOS',
    'TABASCO': 'TABASCO',
    'GUERRERO': 'GUERRERO',
    'OAXACA': 'OAXACA',
    'CHIAPAS': 'CHIAPAS'
}
mexico['ENTIDAD'] = mexico['ENTIDAD'].apply(unidecode).str.upper().replace(entity_mapping)

# Cargar los datos del subconjunto de votos
file_path = 'subconjunto.csv'
sub_data = pd.read_csv(file_path)

# Normalizar los nombres de las entidades en el subconjunto
sub_data['ENTIDAD'] = sub_data['ENTIDAD'].apply(unidecode).str.upper()

# Crear una columna para el ganador en cada estado
sub_data['Claudia_Votes'] = sub_data['COMPETITOR_Votes_2024']
sub_data['Xochitl_Votes'] = sub_data['Xochitl_Opposition_Votes']

# Crear condiciones para asignar colores
def assign_color(row):
    if row['Claudia_Votes'] >= 2 * row['Xochitl_Votes']:
        return 'red'  # Claudia superó a Xochitl por el doble o más
    elif row['Claudia_Votes'] > row['Xochitl_Votes']:
        return 'yellow'  # Claudia superó a Xochitl por menos del doble
    else:
        return 'green'  # Xochitl ganó

sub_data['color'] = sub_data.apply(assign_color, axis=1)

# Verificar los datos del subconjunto con los colores asignados
print("Datos del subconjunto con colores asignados:")
print(sub_data[['ENTIDAD', 'Claudia_Votes', 'Xochitl_Votes', 'color']])

# Unir los datos con el shapefile de México
mexico = mexico.merge(sub_data[['ENTIDAD', 'color']], on='ENTIDAD', how='left')

# Verificar la unión y los colores después de la unión
print("Datos combinados después de la unión:")
print(mexico[['ENTIDAD', 'color']].head(32))

# Crear el gráfico simplificado
fig, ax = plt.subplots(1, 1, figsize=(15, 15))
mexico.boundary.plot(ax=ax, linewidth=1)
mexico.plot(column='color', ax=ax, legend=False, edgecolor='black')

# Personalizar la leyenda
legend_patches = [
    mpatches.Patch(color='red', label='Claudia superó a Xochitl por el doble o más'),
    mpatches.Patch(color='yellow', label='Claudia superó a Xochitl por menos del doble'),
    mpatches.Patch(color='green', label='Xochitl ganó')
]

ax.legend(handles=legend_patches, loc='lower left')

# Eliminar los ejes
ax.set_axis_off()

plt.show()
# Out:
# Datos del subconjunto con colores asignados:
#                ENTIDAD  Claudia_Votes  Xochitl_Votes   color
# 0       AGUASCALIENTES         270389         294746   green
# 1      BAJA CALIFORNIA         862661         290698     red
# 2  BAJA CALIFORNIA SUR         175755          90838  yellow
# 3             CAMPECHE         240693          62268     red
# 4              CHIAPAS        1519559         355592     red
# 5            CHIHUAHUA         744823         495324  yellow
# 6     CIUDAD DE MEXICO        2978243        1862780  yellow
# 7             COAHUILA         813432         595270  yellow
# 8               COLIMA         182063         102288  yellow
# 9              DURANGO         402566         227617  yellow
# Datos combinados después de la unión:
#             ENTIDAD   color
# 0   BAJA CALIFORNIA     red
# 1   BAJA CALIFORNIA     red
# 2   BAJA CALIFORNIA     red
# 3   BAJA CALIFORNIA     red
# 4   BAJA CALIFORNIA     red
# 5            SONORA     NaN
# ...

# %%
import geopandas as gpd
import pandas as pd
from unidecode import unidecode
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# Cargar el shapefile de México
mexico_shapefile_path = './dest_2010gw/dest_2010gw.shp'
mexico = gpd.read_file(mexico_shapefile_path)

# Normalizar y mapear los nombres de las entidades en el shapefile
entity_mapping = {
    'BAJA CALIFORNIA': 'BAJA CALIFORNIA',
    'SONORA': 'SONORA',
    'CHIHUAHUA': 'CHIHUAHUA',
    'COAHUILA DE ZARAGOZA': 'COAHUILA',
    'BAJA CALIFORNIA SUR': 'BAJA CALIFORNIA SUR',
    'NUEVO LEON': 'NUEVO LEON',
    'TAMAULIPAS': 'TAMAULIPAS',
    'SINALOA': 'SINALOA',
    'DURANGO': 'DURANGO',
    'ZACATECAS': 'ZACATECAS',
    'SAN LUIS POTOSI': 'SAN LUIS POTOSI',
    'NAYARIT': 'NAYARIT',
    'JALISCO': 'JALISCO',
    'VERACRUZ DE IGNACIO DE LA LLAVE': 'VERACRUZ',
    'AGUASCALIENTES': 'AGUASCALIENTES',
    'QUINTANA ROO': 'QUINTANA ROO',
    'YUCATAN': 'YUCATAN',
    'GUANAJUATO': 'GUANAJUATO',
    'QUERETARO DE ARTEAGA': 'QUERETARO',
    'CAMPECHE': 'CAMPECHE',
    'HIDALGO': 'HIDALGO',
    'PUEBLA': 'PUEBLA',
    'MICHOACAN DE OCAMPO': 'MICHOACAN',
    'MEXICO': 'MEXICO',
    'TLAXCALA': 'TLAXCALA',
    'DISTRITO FEDERAL': 'CIUDAD DE MEXICO',
    'COLIMA': 'COLIMA',
    'MORELOS': 'MORELOS',
    'TABASCO': 'TABASCO',
    'GUERRERO': 'GUERRERO',
    'OAXACA': 'OAXACA',
    'CHIAPAS': 'CHIAPAS'
}
mexico['ENTIDAD'] = mexico['ENTIDAD'].apply(unidecode).str.upper().replace(entity_mapping)

# Cargar los datos del subconjunto de votos
file_path = 'subconjunto.csv'
sub_data = pd.read_csv(file_path)

# Normalizar los nombres de las entidades en el subconjunto
sub_data['ENTIDAD'] = sub_data['ENTIDAD'].apply(unidecode).str.upper()

# Crear una columna para el ganador en cada estado
sub_data['Claudia_Votes'] = sub_data['COMPETITOR_Votes_2024']
sub_data['Xochitl_Votes'] = sub_data['Xochitl_Opposition_Votes']

# Crear condiciones para asignar colores
def assign_color(row):
    if row['Claudia_Votes'] >= 2 * row['Xochitl_Votes']:
        return 'red'  # Claudia superó a Xochitl por el doble o más
    elif row['Claudia_Votes'] > row['Xochitl_Votes']:
        return 'yellow'  # Claudia superó a Xochitl por menos del doble
    else:
        return 'green'  # Xochitl ganó

sub_data['color'] = sub_data.apply(assign_color, axis=1)

# Verificar los datos del subconjunto con los colores asignados
print("Datos del subconjunto con colores asignados:")
print(sub_data[['ENTIDAD', 'Claudia_Votes', 'Xochitl_Votes', 'color']])

# Unir los datos con el shapefile de México
mexico = mexico.merge(sub_data[['ENTIDAD', 'color']], on='ENTIDAD', how='left')

# Verificar la unión y los colores después de la unión
print("Datos combinados después de la unión:")
print(mexico[['ENTIDAD', 'color']].head(32))

# Crear el gráfico simplificado
fig, ax = plt.subplots(1, 1, figsize=(15, 15))
mexico.boundary.plot(ax=ax, linewidth=1)
mexico.plot(column='color', ax=ax, legend=False, edgecolor='black')

# Personalizar la leyenda
legend_patches = [
    mpatches.Patch(color='red', label='Claudia superó a Xochitl por el doble o más'),
    mpatches.Patch(color='yellow', label='Claudia superó a Xochitl por menos del doble'),
    mpatches.Patch(color='green', label='Xochitl ganó')
]

ax.legend(handles=legend_patches, loc='lower left')

# Eliminar los ejes
ax.set_axis_off()

plt.show()
# Out:
# Datos del subconjunto con colores asignados:
#                ENTIDAD  Claudia_Votes  Xochitl_Votes   color
# 0       AGUASCALIENTES         270389         294746   green
# 1      BAJA CALIFORNIA         862661         290698     red
# 2  BAJA CALIFORNIA SUR         175755          90838  yellow
# 3             CAMPECHE         240693          62268     red
# 4              CHIAPAS        1519559         355592     red
# 5            CHIHUAHUA         744823         495324  yellow
# 6     CIUDAD DE MEXICO        2978243        1862780  yellow
# 7             COAHUILA         813432         595270  yellow
# 8               COLIMA         182063         102288  yellow
# 9              DURANGO         402566         227617  yellow
# Datos combinados después de la unión:
#             ENTIDAD   color
# 0   BAJA CALIFORNIA     red
# 1   BAJA CALIFORNIA     red
# 2   BAJA CALIFORNIA     red
# 3   BAJA CALIFORNIA     red
# 4   BAJA CALIFORNIA     red
# 5            SONORA     NaN
# ...

# %%
import geopandas as gpd
import pandas as pd
from unidecode import unidecode
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# Cargar el shapefile de México
mexico_shapefile_path = './dest_2010gw/dest_2010gw.shp'
mexico = gpd.read_file(mexico_shapefile_path)

# Normalizar y mapear los nombres de las entidades en el shapefile
entity_mapping = {
    'BAJA CALIFORNIA': 'BAJA CALIFORNIA',
    'SONORA': 'SONORA',
    'CHIHUAHUA': 'CHIHUAHUA',
    'COAHUILA DE ZARAGOZA': 'COAHUILA',
    'BAJA CALIFORNIA SUR': 'BAJA CALIFORNIA SUR',
    'NUEVO LEON': 'NUEVO LEON',
    'TAMAULIPAS': 'TAMAULIPAS',
    'SINALOA': 'SINALOA',
    'DURANGO': 'DURANGO',
    'ZACATECAS': 'ZACATECAS',
    'SAN LUIS POTOSI': 'SAN LUIS POTOSI',
    'NAYARIT': 'NAYARIT',
    'JALISCO': 'JALISCO',
    'VERACRUZ DE IGNACIO DE LA LLAVE': 'VERACRUZ',
    'AGUASCALIENTES': 'AGUASCALIENTES',
    'QUINTANA ROO': 'QUINTANA ROO',
    'YUCATAN': 'YUCATAN',
    'GUANAJUATO': 'GUANAJUATO',
    'QUERETARO DE ARTEAGA': 'QUERETARO',
    'CAMPECHE': 'CAMPECHE',
    'HIDALGO': 'HIDALGO',
    'PUEBLA': 'PUEBLA',
    'MICHOACAN DE OCAMPO': 'MICHOACAN',
    'MEXICO': 'MEXICO',
    'TLAXCALA': 'TLAXCALA',
    'DISTRITO FEDERAL': 'CIUDAD DE MEXICO',
    'COLIMA': 'COLIMA',
    'MORELOS': 'MORELOS',
    'TABASCO': 'TABASCO',
    'GUERRERO': 'GUERRERO',
    'OAXACA': 'OAXACA',
    'CHIAPAS': 'CHIAPAS'
}
mexico['ENTIDAD'] = mexico['ENTIDAD'].apply(unidecode).str.upper().replace(entity_mapping)

# Cargar los datos del subconjunto de votos
file_path = 'subconjunto.csv'
sub_data = pd.read_csv(file_path)

# Normalizar los nombres de las entidades en el subconjunto
sub_data['ENTIDAD'] = sub_data['ENTIDAD'].apply(unidecode).str.upper()

# Crear una columna para el ganador en cada estado
sub_data['Claudia_Votes'] = sub_data['COMPETITOR_Votes_2024']
sub_data['Xochitl_Votes'] = sub_data['Xochitl_Opposition_Votes']

# Crear condiciones para asignar colores
def assign_color(row):
    if row['Claudia_Votes'] >= 2 * row['Xochitl_Votes']:
        return 'red'  # Claudia superó a Xochitl por el doble o más
    elif row['Claudia_Votes'] > row['Xochitl_Votes']:
        return 'yellow'  # Claudia superó a Xochitl por menos del doble
    else:
        return 'green'  # Xochitl ganó

sub_data['color'] = sub_data.apply(assign_color, axis=1)

# Verificar los datos del subconjunto con los colores asignados
print("Datos del subconjunto con colores asignados:")
print(sub_data[['ENTIDAD', 'Claudia_Votes', 'Xochitl_Votes', 'color']])

# Unir los datos con el shapefile de México
mexico = mexico.merge(sub_data[['ENTIDAD', 'color']], on='ENTIDAD', how='left')

# Verificar la unión y los colores después de la unión
print("Datos combinados después de la unión:")
print(mexico[['ENTIDAD', 'color']].head(32))

# Crear el gráfico simplificado
fig, ax = plt.subplots(1, 1, figsize=(15, 15))
mexico.boundary.plot(ax=ax, linewidth=1)
mexico.plot(column='color', ax=ax, legend=False, edgecolor='black')

# Personalizar la leyenda
legend_patches = [
    mpatches.Patch(color='red', label='Claudia superó a Xochitl por el doble o más'),
    mpatches.Patch(color='yellow', label='Claudia superó a Xochitl por menos del doble'),
    mpatches.Patch(color='green', label='Xochitl ganó')
]

ax.legend(handles=legend_patches, loc='lower left')

# Eliminar los ejes
ax.set_axis_off()

plt.show()
# Out:
# Datos del subconjunto con colores asignados:
#                ENTIDAD  Claudia_Votes  Xochitl_Votes   color
# 0       AGUASCALIENTES         270389         294746   green
# 1      BAJA CALIFORNIA         862661         290698     red
# 2  BAJA CALIFORNIA SUR         175755          90838  yellow
# 3             CAMPECHE         240693          62268     red
# 4              CHIAPAS        1519559         355592     red
# 5            CHIHUAHUA         744823         495324  yellow
# 6     CIUDAD DE MEXICO        2978243        1862780  yellow
# 7             COAHUILA         813432         595270  yellow
# 8               COLIMA         182063         102288  yellow
# 9              DURANGO         402566         227617  yellow
# Datos combinados después de la unión:
#             ENTIDAD   color
# 0   BAJA CALIFORNIA     red
# 1   BAJA CALIFORNIA     red
# 2   BAJA CALIFORNIA     red
# 3   BAJA CALIFORNIA     red
# 4   BAJA CALIFORNIA     red
# 5            SONORA     NaN
# ...

# %%
import geopandas as gpd
import pandas as pd
from unidecode import unidecode
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# Cargar el shapefile de México
mexico_shapefile_path = './dest_2010gw/dest_2010gw.shp'
mexico = gpd.read_file(mexico_shapefile_path)

# Normalizar y mapear los nombres de las entidades en el shapefile
entity_mapping = {
    'BAJA CALIFORNIA': 'BAJA CALIFORNIA',
    'SONORA': 'SONORA',
    'CHIHUAHUA': 'CHIHUAHUA',
    'COAHUILA DE ZARAGOZA': 'COAHUILA',
    'BAJA CALIFORNIA SUR': 'BAJA CALIFORNIA SUR',
    'NUEVO LEON': 'NUEVO LEON',
    'TAMAULIPAS': 'TAMAULIPAS',
    'SINALOA': 'SINALOA',
    'DURANGO': 'DURANGO',
    'ZACATECAS': 'ZACATECAS',
    'SAN LUIS POTOSI': 'SAN LUIS POTOSI',
    'NAYARIT': 'NAYARIT',
    'JALISCO': 'JALISCO',
    'VERACRUZ DE IGNACIO DE LA LLAVE': 'VERACRUZ',
    'AGUASCALIENTES': 'AGUASCALIENTES',
    'QUINTANA ROO': 'QUINTANA ROO',
    'YUCATAN': 'YUCATAN',
    'GUANAJUATO': 'GUANAJUATO',
    'QUERETARO DE ARTEAGA': 'QUERETARO',
    'CAMPECHE': 'CAMPECHE',
    'HIDALGO': 'HIDALGO',
    'PUEBLA': 'PUEBLA',
    'MICHOACAN DE OCAMPO': 'MICHOACAN',
    'MEXICO': 'MEXICO',
    'TLAXCALA': 'TLAXCALA',
    'DISTRITO FEDERAL': 'CIUDAD DE MEXICO',
    'COLIMA': 'COLIMA',
    'MORELOS': 'MORELOS',
    'TABASCO': 'TABASCO',
    'GUERRERO': 'GUERRERO',
    'OAXACA': 'OAXACA',
    'CHIAPAS': 'CHIAPAS'
}
mexico['ENTIDAD'] = mexico['ENTIDAD'].apply(unidecode).str.upper().replace(entity_mapping)

# Cargar los datos del subconjunto de votos
file_path = 'ELECTIONS_vs_SOCIODEMOGRAPHICS_ALT2.csv'
sub_data = pd.read_csv(file_path)

# Normalizar los nombres de las entidades en el subconjunto
sub_data['ENTIDAD'] = sub_data['ENTIDAD'].apply(unidecode).str.upper()

# Crear una columna para el ganador en cada estado
sub_data['Claudia_Votes'] = sub_data['COMPETITOR_Votes_2024']
sub_data['Xochitl_Votes'] = sub_data['Xochitl_Opposition_Votes']

# Crear condiciones para asignar colores
def assign_color(row):
    if row['Claudia_Votes'] >= 2 * row['Xochitl_Votes']:
        return '#8B4513'  # Café para Claudia superó a Xochitl por el doble o más
    elif row['Claudia_Votes'] > row['Xochitl_Votes']:
        return '#1f77b4'  # Azul fuerte para Claudia superó a Xochitl por menos del doble
    else:
        return '#17becf'  # Azul clarito para Xochitl ganó

sub_data['color'] = sub_data.apply(assign_color, axis=1)

# Verificar los datos del subconjunto con los colores asignados
print("Datos del subconjunto con colores asignados:")
print(sub_data[['ENTIDAD', 'Claudia_Votes', 'Xochitl_Votes', 'color']])

# Unir los datos con el shapefile de México
mexico = mexico.merge(sub_data[['ENTIDAD', 'color']], on='ENTIDAD', how='left')

# Verificar la unión y los colores después de la unión
print("Datos combinados después de la unión:")
print(mexico[['ENTIDAD', 'color']].head(32))

# Crear el gráfico simplificado
fig, ax = plt.subplots(1, 1, figsize=(15, 15))
mexico.boundary.plot(ax=ax, linewidth=1)
mexico.plot(column='color', ax=ax, legend=False, edgecolor='black')

# Personalizar la leyenda
legend_patches = [
    mpatches.Patch(color='#8B4513', label='Claudia superó a Xochitl por el doble o más'),
    mpatches.Patch(color='#1f77b4', label='Claudia superó a Xochitl por menos del doble'),
    mpatches.Patch(color='#17becf', label='Xochitl ganó')
]

ax.legend(handles=legend_patches, loc='lower left')

# Eliminar los ejes
ax.set_axis_off()

plt.show()
# Out:
# Datos del subconjunto con colores asignados:
#                 ENTIDAD  Claudia_Votes  Xochitl_Votes    color
# 0        AGUASCALIENTES         270389         294746  #17becf
# 1       BAJA CALIFORNIA         862661         290698  #8B4513
# 2   BAJA CALIFORNIA SUR         175755          90838  #1f77b4
# 3              CAMPECHE         240693          62268  #8B4513
# 4               CHIAPAS        1519559         355592  #8B4513
# 5             CHIHUAHUA         744823         495324  #1f77b4
# 6      CIUDAD DE MEXICO        2978243        1862780  #1f77b4
# 7              COAHUILA         813432         595270  #1f77b4
# 8                COLIMA         182063         102288  #1f77b4
# 9               DURANGO         402566         227617  #1f77b4
# 10           GUANAJUATO        1223770        1057455  #1f77b4
# 11             GUERRERO        1039283         276953  #8B4513
# 12              HIDALGO        1001963         299831  #8B4513
# ...

# %%
import geopandas as gpd
import pandas as pd
from unidecode import unidecode
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# Cargar el shapefile de México
mexico_shapefile_path = './dest_2010gw/dest_2010gw.shp'
mexico = gpd.read_file(mexico_shapefile_path)

# Normalizar y mapear los nombres de las entidades en el shapefile
entity_mapping = {
    'BAJA CALIFORNIA': 'BAJA CALIFORNIA',
    'SONORA': 'SONORA',
    'CHIHUAHUA': 'CHIHUAHUA',
    'COAHUILA DE ZARAGOZA': 'COAHUILA',
    'BAJA CALIFORNIA SUR': 'BAJA CALIFORNIA SUR',
    'NUEVO LEON': 'NUEVO LEON',
    'TAMAULIPAS': 'TAMAULIPAS',
    'SINALOA': 'SINALOA',
    'DURANGO': 'DURANGO',
    'ZACATECAS': 'ZACATECAS',
    'SAN LUIS POTOSI': 'SAN LUIS POTOSI',
    'NAYARIT': 'NAYARIT',
    'JALISCO': 'JALISCO',
    'VERACRUZ DE IGNACIO DE LA LLAVE': 'VERACRUZ',
    'AGUASCALIENTES': 'AGUASCALIENTES',
    'QUINTANA ROO': 'QUINTANA ROO',
    'YUCATAN': 'YUCATAN',
    'GUANAJUATO': 'GUANAJUATO',
    'QUERETARO DE ARTEAGA': 'QUERETARO',
    'CAMPECHE': 'CAMPECHE',
    'HIDALGO': 'HIDALGO',
    'PUEBLA': 'PUEBLA',
    'MICHOACAN DE OCAMPO': 'MICHOACAN',
    'MEXICO': 'MEXICO',
    'TLAXCALA': 'TLAXCALA',
    'DISTRITO FEDERAL': 'CIUDAD DE MEXICO',
    'COLIMA': 'COLIMA',
    'MORELOS': 'MORELOS',
    'TABASCO': 'TABASCO',
    'GUERRERO': 'GUERRERO',
    'OAXACA': 'OAXACA',
    'CHIAPAS': 'CHIAPAS'
}
mexico['ENTIDAD'] = mexico['ENTIDAD'].apply(unidecode).str.upper().replace(entity_mapping)

# Cargar los datos del subconjunto de votos
file_path = 'ELECTIONS_vs_SOCIODEMOGRAPHICS_ALT2.csv'
sub_data = pd.read_csv(file_path)

# Normalizar los nombres de las entidades en el subconjunto
sub_data['ENTIDAD'] = sub_data['ENTIDAD'].apply(unidecode).str.upper()

# Crear una columna para el ganador en cada estado
sub_data['Claudia_Votes'] = sub_data['COMPETITOR_Votes_2024']
sub_data['Xochitl_Votes'] = sub_data['Xochitl_Opposition_Votes']

# Crear condiciones para asignar colores
def assign_color(row):
    if row['Claudia_Votes'] >= 2 * row['Xochitl_Votes']:
        return '#1f77b4'  # Azul fuerte para Claudia superó a Xochitl por el doble o más
    elif row['Claudia_Votes'] > row['Xochitl_Votes']:
        return '#17becf'  # Azul clarito para Claudia superó a Xochitl por menos del doble
    else:
        return '#8B4513'  # Café para Xochitl ganó

sub_data['color'] = sub_data.apply(assign_color, axis=1)

# Verificar los datos del subconjunto con los colores asignados
print("Datos del subconjunto con colores asignados:")
print(sub_data[['ENTIDAD', 'Claudia_Votes', 'Xochitl_Votes', 'color']])

# Unir los datos con el shapefile de México
mexico = mexico.merge(sub_data[['ENTIDAD', 'color']], on='ENTIDAD', how='left')

# Verificar la unión y los colores después de la unión
print("Datos combinados después de la unión:")
print(mexico[['ENTIDAD', 'color']].head(32))

# Crear el gráfico simplificado
fig, ax = plt.subplots(1, 1, figsize=(15, 15))
mexico.boundary.plot(ax=ax, linewidth=1)
mexico.plot(column='color', ax=ax, legend=False, edgecolor='black')

# Personalizar la leyenda
legend_patches = [
    mpatches.Patch(color='#8B4513', label='Claudia superó a Xochitl por el doble o más'),
    mpatches.Patch(color='#1f77b4', label='Claudia superó a Xochitl por menos del doble'),
    mpatches.Patch(color='#17becf', label='Xochitl ganó')
]

ax.legend(handles=legend_patches, loc='lower left')

# Eliminar los ejes
ax.set_axis_off()

plt.show()
# Out:
# Datos del subconjunto con colores asignados:
#                 ENTIDAD  Claudia_Votes  Xochitl_Votes    color
# 0        AGUASCALIENTES         270389         294746  #8B4513
# 1       BAJA CALIFORNIA         862661         290698  #1f77b4
# 2   BAJA CALIFORNIA SUR         175755          90838  #17becf
# 3              CAMPECHE         240693          62268  #1f77b4
# 4               CHIAPAS        1519559         355592  #1f77b4
# 5             CHIHUAHUA         744823         495324  #17becf
# 6      CIUDAD DE MEXICO        2978243        1862780  #17becf
# 7              COAHUILA         813432         595270  #17becf
# 8                COLIMA         182063         102288  #17becf
# 9               DURANGO         402566         227617  #17becf
# 10           GUANAJUATO        1223770        1057455  #17becf
# 11             GUERRERO        1039283         276953  #1f77b4
# 12              HIDALGO        1001963         299831  #1f77b4
# ...

# %%
import geopandas as gpd
import pandas as pd
from unidecode import unidecode
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# Cargar el shapefile de México
mexico_shapefile_path = './dest_2010gw/dest_2010gw.shp'
mexico = gpd.read_file(mexico_shapefile_path)

# Normalizar y mapear los nombres de las entidades en el shapefile
entity_mapping = {
    'BAJA CALIFORNIA': 'BAJA CALIFORNIA',
    'SONORA': 'SONORA',
    'CHIHUAHUA': 'CHIHUAHUA',
    'COAHUILA DE ZARAGOZA': 'COAHUILA',
    'BAJA CALIFORNIA SUR': 'BAJA CALIFORNIA SUR',
    'NUEVO LEON': 'NUEVO LEON',
    'TAMAULIPAS': 'TAMAULIPAS',
    'SINALOA': 'SINALOA',
    'DURANGO': 'DURANGO',
    'ZACATECAS': 'ZACATECAS',
    'SAN LUIS POTOSI': 'SAN LUIS POTOSI',
    'NAYARIT': 'NAYARIT',
    'JALISCO': 'JALISCO',
    'VERACRUZ DE IGNACIO DE LA LLAVE': 'VERACRUZ',
    'AGUASCALIENTES': 'AGUASCALIENTES',
    'QUINTANA ROO': 'QUINTANA ROO',
    'YUCATAN': 'YUCATAN',
    'GUANAJUATO': 'GUANAJUATO',
    'QUERETARO DE ARTEAGA': 'QUERETARO',
    'CAMPECHE': 'CAMPECHE',
    'HIDALGO': 'HIDALGO',
    'PUEBLA': 'PUEBLA',
    'MICHOACAN DE OCAMPO': 'MICHOACAN',
    'MEXICO': 'MEXICO',
    'TLAXCALA': 'TLAXCALA',
    'DISTRITO FEDERAL': 'CIUDAD DE MEXICO',
    'COLIMA': 'COLIMA',
    'MORELOS': 'MORELOS',
    'TABASCO': 'TABASCO',
    'GUERRERO': 'GUERRERO',
    'OAXACA': 'OAXACA',
    'CHIAPAS': 'CHIAPAS'
}
mexico['ENTIDAD'] = mexico['ENTIDAD'].apply(unidecode).str.upper().replace(entity_mapping)

# Cargar los datos del subconjunto de votos
file_path = 'ELECTIONS_vs_SOCIODEMOGRAPHICS_ALT2.csv'
sub_data = pd.read_csv(file_path)

# Normalizar los nombres de las entidades en el subconjunto
sub_data['ENTIDAD'] = sub_data['ENTIDAD'].apply(unidecode).str.upper()

# Calcular los percentiles para definir los rangos del semáforo
pib_33 = sub_data['GDP_2024'].quantile(0.33)
pib_66 = sub_data['GDP_2024'].quantile(0.66)

# Crear condiciones para asignar colores
def assign_color_pib(row):
    if row['GDP_2024'] < pib_33:
        return 'red'  # PIB bajo
    elif row['GDP_2024'] < pib_66:
        return 'yellow'  # PIB medio
    else:
        return 'green'  # PIB alto

sub_data['color_pib'] = sub_data.apply(assign_color_pib, axis=1)

# Verificar los datos del subconjunto con los colores asignados
print("Datos del subconjunto con colores asignados:")
print(sub_data[['ENTIDAD', 'GDP_2024', 'color_pib']])

# Unir los datos con el shapefile de México
mexico = mexico.merge(sub_data[['ENTIDAD', 'color_pib']], on='ENTIDAD', how='left')

# Verificar la unión y los colores después de la unión
print("Datos combinados después de la unión:")
print(mexico[['ENTIDAD', 'color_pib']].head(32))

# Crear el gráfico simplificado
fig, ax = plt.subplots(1, 1, figsize=(15, 15))
mexico.boundary.plot(ax=ax, linewidth=1)
mexico.plot(column='color_pib', ax=ax, legend=False, edgecolor='black')

# Personalizar la leyenda
legend_patches = [
    mpatches.Patch(color='red', label='PIB bajo'),
    mpatches.Patch(color='yellow', label='PIB medio'),
    mpatches.Patch(color='green', label='PIB alto')
]

ax.legend(handles=legend_patches, loc='lower left')

# Eliminar los ejes
ax.set_axis_off()

plt.show()
# Out:
# Datos del subconjunto con colores asignados:
#                 ENTIDAD  GDP_2024 color_pib
# 0        AGUASCALIENTES    316500       red
# 1       BAJA CALIFORNIA    929459     green
# 2   BAJA CALIFORNIA SUR    177421       red
# 3              CAMPECHE    473101    yellow
# 4               CHIAPAS    368789       red
# 5             CHIHUAHUA    919617     green
# 6      CIUDAD DE MEXICO   3640388     green
# 7              COAHUILA    922287     green
# 8                COLIMA    148130       red
# 9               DURANGO    296963       red
# 10           GUANAJUATO   1128686     green
# 11             GUERRERO    306831       red
# 12              HIDALGO    426819    yellow
# 13              JALISCO   1783505     green
# 14               MEXICO   2184863     green
# 15            MICHOACAN    646901    yellow
# 16              MORELOS    256740       red
# 17              NAYARIT    161869       red
# 18           NUEVO LEON   1945060     green
# ...

# %%
import geopandas as gpd
import pandas as pd
from unidecode import unidecode
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# Cargar el shapefile de México
mexico_shapefile_path = './dest_2010gw/dest_2010gw.shp'
mexico = gpd.read_file(mexico_shapefile_path)

# Normalizar y mapear los nombres de las entidades en el shapefile
entity_mapping = {
    'BAJA CALIFORNIA': 'BAJA CALIFORNIA',
    'SONORA': 'SONORA',
    'CHIHUAHUA': 'CHIHUAHUA',
    'COAHUILA DE ZARAGOZA': 'COAHUILA',
    'BAJA CALIFORNIA SUR': 'BAJA CALIFORNIA SUR',
    'NUEVO LEON': 'NUEVO LEON',
    'TAMAULIPAS': 'TAMAULIPAS',
    'SINALOA': 'SINALOA',
    'DURANGO': 'DURANGO',
    'ZACATECAS': 'ZACATECAS',
    'SAN LUIS POTOSI': 'SAN LUIS POTOSI',
    'NAYARIT': 'NAYARIT',
    'JALISCO': 'JALISCO',
    'VERACRUZ DE IGNACIO DE LA LLAVE': 'VERACRUZ',
    'AGUASCALIENTES': 'AGUASCALIENTES',
    'QUINTANA ROO': 'QUINTANA ROO',
    'YUCATAN': 'YUCATAN',
    'GUANAJUATO': 'GUANAJUATO',
    'QUERETARO DE ARTEAGA': 'QUERETARO',
    'CAMPECHE': 'CAMPECHE',
    'HIDALGO': 'HIDALGO',
    'PUEBLA': 'PUEBLA',
    'MICHOACAN DE OCAMPO': 'MICHOACAN',
    'MEXICO': 'MEXICO',
    'TLAXCALA': 'TLAXCALA',
    'DISTRITO FEDERAL': 'CIUDAD DE MEXICO',
    'COLIMA': 'COLIMA',
    'MORELOS': 'MORELOS',
    'TABASCO': 'TABASCO',
    'GUERRERO': 'GUERRERO',
    'OAXACA': 'OAXACA',
    'CHIAPAS': 'CHIAPAS'
}
mexico['ENTIDAD'] = mexico['ENTIDAD'].apply(unidecode).str.upper().replace(entity_mapping)

# Cargar los datos del subconjunto de votos
file_path = 'ELECTIONS_vs_SOCIODEMOGRAPHICS_ALT2.csv'
sub_data = pd.read_csv(file_path)

# Normalizar los nombres de las entidades en el subconjunto
sub_data['ENTIDAD'] = sub_data['ENTIDAD'].apply(unidecode).str.upper()

# Calcular los percentiles para definir los rangos de pobreza
poverty_33 = sub_data['Poberty_Habitants'].quantile(0.33)
poverty_66 = sub_data['Poberty_Habitants'].quantile(0.66)

# Crear condiciones para asignar colores
def assign_color_poverty(row):
    if row['Poberty_Habitants'] < poverty_33:
        return '#17becf'  # Azul claro para baja pobreza
    elif row['Poberty_Habitants'] < poverty_66:
        return '#1f77b4'  # Azul fuerte para pobreza media
    else:
        return '#8B4513'  # Café para alta pobreza

sub_data['color_poverty'] = sub_data.apply(assign_color_poverty, axis=1)

# Verificar los datos del subconjunto con los colores asignados
print("Datos del subconjunto con colores asignados:")
print(sub_data[['ENTIDAD', 'Poberty_Habitants', 'color_poverty']])

# Unir los datos con el shapefile de México
mexico = mexico.merge(sub_data[['ENTIDAD', 'color_poverty']], on='ENTIDAD', how='left')

# Verificar la unión y los colores después de la unión
print("Datos combinados después de la unión:")
print(mexico[['ENTIDAD', 'color_poverty']].head(32))

# Crear el gráfico simplificado
fig, ax = plt.subplots(1, 1, figsize=(15, 15))
mexico.boundary.plot(ax=ax, linewidth=1)
mexico.plot(column='color_poverty', ax=ax, legend=False, edgecolor='black')

# Personalizar la leyenda
legend_patches = [
    mpatches.Patch(color='#8B4513', label='Pobreza baja'),
    mpatches.Patch(color='#1f77b4', label='Pobreza media'),
    mpatches.Patch(color='#17becf', label='Pobreza alta')
]



ax.legend(handles=legend_patches, loc='lower left')

# Eliminar los ejes
ax.set_axis_off()

plt.show()
# Out:
# Datos del subconjunto con colores asignados:
#                 ENTIDAD  Poberty_Habitants color_poverty
# 0        AGUASCALIENTES                326       #17becf
# 1       BAJA CALIFORNIA                461       #17becf
# 2   BAJA CALIFORNIA SUR                106       #17becf
# 3              CAMPECHE                337       #17becf
# 4               CHIAPAS               2231       #8B4513
# 5             CHIHUAHUA                589       #17becf
# 6      CIUDAD DE MEXICO               2071       #8B4513
# 7              COAHUILA                538       #17becf
# 8                COLIMA                149       #17becf
# 9               DURANGO                523       #17becf
# 10           GUANAJUATO               1870       #8B4513
# 11             GUERRERO               1373       #8B4513
# 12              HIDALGO               1080       #8B4513
# 13              JALISCO               1676       #8B4513
# 14               MEXICO               6395       #8B4513
# ...

# %%
import geopandas as gpd
import pandas as pd
from unidecode import unidecode
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.patches as mpatches

# Cargar el shapefile de México
mexico_shapefile_path = './dest_2010gw/dest_2010gw.shp'
mexico = gpd.read_file(mexico_shapefile_path)

# Normalizar y mapear los nombres de las entidades en el shapefile
entity_mapping = {
    'BAJA CALIFORNIA': 'BAJA CALIFORNIA',
    'SONORA': 'SONORA',
    'CHIHUAHUA': 'CHIHUAHUA',
    'COAHUILA DE ZARAGOZA': 'COAHUILA',
    'BAJA CALIFORNIA SUR': 'BAJA CALIFORNIA SUR',
    'NUEVO LEON': 'NUEVO LEON',
    'TAMAULIPAS': 'TAMAULIPAS',
    'SINALOA': 'SINALOA',
    'DURANGO': 'DURANGO',
    'ZACATECAS': 'ZACATECAS',
    'SAN LUIS POTOSI': 'SAN LUIS POTOSI',
    'NAYARIT': 'NAYARIT',
    'JALISCO': 'JALISCO',
    'VERACRUZ DE IGNACIO DE LA LLAVE': 'VERACRUZ',
    'AGUASCALIENTES': 'AGUASCALIENTES',
    'QUINTANA ROO': 'QUINTANA ROO',
    'YUCATAN': 'YUCATAN',
    'GUANAJUATO': 'GUANAJUATO',
    'QUERETARO DE ARTEAGA': 'QUERETARO',
    'CAMPECHE': 'CAMPECHE',
    'HIDALGO': 'HIDALGO',
    'PUEBLA': 'PUEBLA',
    'MICHOACAN DE OCAMPO': 'MICHOACAN',
    'MEXICO': 'MEXICO',
    'TLAXCALA': 'TLAXCALA',
    'DISTRITO FEDERAL': 'CIUDAD DE MEXICO',
    'COLIMA': 'COLIMA',
    'MORELOS': 'MORELOS',
    'TABASCO': 'TABASCO',
    'GUERRERO': 'GUERRERO',
    'OAXACA': 'OAXACA',
    'CHIAPAS': 'CHIAPAS'
}
mexico['ENTIDAD'] = mexico['ENTIDAD'].apply(unidecode).str.upper().replace(entity_mapping)

# Cargar los datos del subconjunto de votos
file_path = 'ELECTIONS_vs_SOCIODEMOGRAPHICS_ALT2.csv'
sub_data = pd.read_csv(file_path)

# Normalizar los nombres de las entidades en el subconjunto
sub_data['ENTIDAD'] = sub_data['ENTIDAD'].apply(unidecode).str.upper()

# Calcular los percentiles para definir los rangos de pobreza
poverty_33 = sub_data['Poberty_Habitants'].quantile(0.33)
poverty_66 = sub_data['Poberty_Habitants'].quantile(0.66)

# Crear condiciones para asignar colores
def assign_color_poverty(row):
    if row['Poberty_Habitants'] < poverty_33:
        return '#17becf'  # Azul claro para baja pobreza
    elif row['Poberty_Habitants'] < poverty_66:
        return '#1f77b4'  # Azul fuerte para pobreza media
    else:
        return '#8B4513'  # Café para alta pobreza

sub_data['color_poverty'] = sub_data.apply(assign_color_poverty, axis=1)

# Verificar los datos del subconjunto con los colores asignados
print("Datos del subconjunto con colores asignados:")
print(sub_data[['ENTIDAD', 'Poberty_Habitants', 'color_poverty']])

# Unir los datos con el shapefile de México
mexico = mexico.merge(sub_data[['ENTIDAD', 'color_poverty']], on='ENTIDAD', how='left')

# Verificar la unión y los colores después de la unión
print("Datos combinados después de la unión:")
print(mexico[['ENTIDAD', 'color_poverty']].head(32))

# Crear el gráfico con seaborn
sns.set(style="white")
fig, ax = plt.subplots(1, 1, figsize=(15, 15))
mexico.boundary.plot(ax=ax, linewidth=1)
mexico.plot(column='color_poverty', ax=ax, legend=False, edgecolor='black')

# Personalizar la leyenda
legend_patches = [
    mpatches.Patch(color='#17becf', label='Pobreza baja'),
    mpatches.Patch(color='#1f77b4', label='Pobreza media'),
    mpatches.Patch(color='#8B4513', label='Pobreza alta')
]

ax.legend(handles=legend_patches, loc='lower left')

# Eliminar los ejes
ax.set_axis_off()

plt.show()
# Out:
# Datos del subconjunto con colores asignados:
#                 ENTIDAD  Poberty_Habitants color_poverty
# 0        AGUASCALIENTES                326       #17becf
# 1       BAJA CALIFORNIA                461       #17becf
# 2   BAJA CALIFORNIA SUR                106       #17becf
# 3              CAMPECHE                337       #17becf
# 4               CHIAPAS               2231       #8B4513
# 5             CHIHUAHUA                589       #17becf
# 6      CIUDAD DE MEXICO               2071       #8B4513
# 7              COAHUILA                538       #17becf
# 8                COLIMA                149       #17becf
# 9               DURANGO                523       #17becf
# 10           GUANAJUATO               1870       #8B4513
# 11             GUERRERO               1373       #8B4513
# 12              HIDALGO               1080       #8B4513
# 13              JALISCO               1676       #8B4513
# 14               MEXICO               6395       #8B4513
# ...

# %%
import geopandas as gpd
import pandas as pd
from unidecode import unidecode
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.patches as mpatches

# Establecer la paleta de colores usando una paleta por defecto de seaborn
sns.set_palette("RdBu", 3)
palette = sns.color_palette("RdBu", 3)

# Cargar el shapefile de México
mexico_shapefile_path = './dest_2010gw/dest_2010gw.shp'
mexico = gpd.read_file(mexico_shapefile_path)

# Normalizar y mapear los nombres de las entidades en el shapefile
entity_mapping = {
    'BAJA CALIFORNIA': 'BAJA CALIFORNIA',
    'SONORA': 'SONORA',
    'CHIHUAHUA': 'CHIHUAHUA',
    'COAHUILA DE ZARAGOZA': 'COAHUILA',
    'BAJA CALIFORNIA SUR': 'BAJA CALIFORNIA SUR',
    'NUEVO LEON': 'NUEVO LEON',
    'TAMAULIPAS': 'TAMAULIPAS',
    'SINALOA': 'SINALOA',
    'DURANGO': 'DURANGO',
    'ZACATECAS': 'ZACATECAS',
    'SAN LUIS POTOSI': 'SAN LUIS POTOSI',
    'NAYARIT': 'NAYARIT',
    'JALISCO': 'JALISCO',
    'VERACRUZ DE IGNACIO DE LA LLAVE': 'VERACRUZ',
    'AGUASCALIENTES': 'AGUASCALIENTES',
    'QUINTANA ROO': 'QUINTANA ROO',
    'YUCATAN': 'YUCATAN',
    'GUANAJUATO': 'GUANAJUATO',
    'QUERETARO DE ARTEAGA': 'QUERETARO',
    'CAMPECHE': 'CAMPECHE',
    'HIDALGO': 'HIDALGO',
    'PUEBLA': 'PUEBLA',
    'MICHOACAN DE OCAMPO': 'MICHOACAN',
    'MEXICO': 'MEXICO',
    'TLAXCALA': 'TLAXCALA',
    'DISTRITO FEDERAL': 'CIUDAD DE MEXICO',
    'COLIMA': 'COLIMA',
    'MORELOS': 'MORELOS',
    'TABASCO': 'TABASCO',
    'GUERRERO': 'GUERRERO',
    'OAXACA': 'OAXACA',
    'CHIAPAS': 'CHIAPAS'
}
mexico['ENTIDAD'] = mexico['ENTIDAD'].apply(unidecode).str.upper().replace(entity_mapping)

# Cargar los datos del subconjunto de votos
file_path = 'ELECTIONS_vs_SOCIODEMOGRAPHICS_ALT2.csv'
sub_data = pd.read_csv(file_path)

# Normalizar los nombres de las entidades en el subconjunto
sub_data['ENTIDAD'] = sub_data['ENTIDAD'].apply(unidecode).str.upper()

# Crear una columna para el ganador en cada estado
sub_data['Claudia_Votes'] = sub_data['COMPETITOR_Votes_2024']
sub_data['Xochitl_Votes'] = sub_data['Xochitl_Opposition_Votes']

# Asignar colores basados en la paleta definida
def assign_color(row):
    if row['Claudia_Votes'] >= 2 * row['Xochitl_Votes']:
        return palette[2]  # Rojo fuerte para Claudia superó a Xochitl por el doble o más
    elif row['Claudia_Votes'] > row['Xochitl_Votes']:
        return palette[1]  # Amarillo (intermedio en la paleta) para Claudia superó a Xochitl por menos del doble
    else:
        return palette[0]  # Azul fuerte para Xochitl ganó

sub_data['color'] = sub_data.apply(assign_color, axis=1)

# Verificar los datos del subconjunto con los colores asignados
print("Datos del subconjunto con colores asignados:")
print(sub_data[['ENTIDAD', 'Claudia_Votes', 'Xochitl_Votes', 'color']])

# Unir los datos con el shapefile de México
mexico = mexico.merge(sub_data[['ENTIDAD', 'color']], on='ENTIDAD', how='left')

# Verificar la unión y los colores después de la unión
print("Datos combinados después de la unión:")
print(mexico[['ENTIDAD', 'color']].head(32))

# Crear el gráfico con seaborn
sns.set(style="white")
fig, ax = plt.subplots(1, 1, figsize=(15, 15))
mexico.boundary.plot(ax=ax, linewidth=1)
mexico.plot(column='color', ax=ax, legend=False, edgecolor='black')

# Personalizar la leyenda
legend_patches = [
    mpatches.Patch(color=palette[2], label='Claudia superó a Xochitl por el doble o más'),
    mpatches.Patch(color=palette[1], label='Claudia superó a Xochitl por menos del doble'),
    mpatches.Patch(color=palette[0], label='Xochitl ganó')
]

ax.legend(handles=legend_patches, loc='lower left')

# Eliminar los ejes
ax.set_axis_off()

plt.show()
# Out:
# Datos del subconjunto con colores asignados:
#                 ENTIDAD  Claudia_Votes  Xochitl_Votes  \
# 0        AGUASCALIENTES         270389         294746
# 1       BAJA CALIFORNIA         862661         290698
# 2   BAJA CALIFORNIA SUR         175755          90838
# 3              CAMPECHE         240693          62268
# 4               CHIAPAS        1519559         355592
# 5             CHIHUAHUA         744823         495324
# 6      CIUDAD DE MEXICO        2978243        1862780
# 7              COAHUILA         813432         595270
# 8                COLIMA         182063         102288
# 9               DURANGO         402566         227617
# 10           GUANAJUATO        1223770        1057455
# 11             GUERRERO        1039283         276953
# 12              HIDALGO        1001963         299831
# 13              JALISCO        1592942        1303587
# 14               MEXICO        4916419        2177817
# ...
