# %%
# !pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Ignoring invalid distribution -cxt (/home/jj/.local/lib/python3.10/site-packages)
# Requirement already satisfied: nltk in /home/jj/.local/lib/python3.10/site-packages (3.8.1)
# Requirement already satisfied: click in /home/jj/.local/lib/python3.10/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /home/jj/.local/lib/python3.10/site-packages (from nltk) (1.4.0)
# Requirement already satisfied: regex>=2021.8.3 in /home/jj/.local/lib/python3.10/site-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in /home/jj/.local/lib/python3.10/site-packages (from nltk) (4.66.2)
# WARNING: Ignoring invalid distribution -cxt (/home/jj/.local/lib/python3.10/site-packages)

# %%
# Importing necessary library
import pandas as pd
import numpy as np
import nltk
import os
import nltk.corpus

import nltk
nltk.download('punkt')

# sample text for performing tokenization
text = "In Brazil they drive on the right-hand side of the road. Brazil has a large coastline on the eastern side of South America"
# importing word_tokenize from nltk
from nltk.tokenize import word_tokenize
# Passing the string text into word tokenize for breaking the sentences
token = word_tokenize(text)
token
# Out:
# [nltk_data] Downloading package punkt to /home/jj/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ['In',
#  'Brazil',
#  'they',
#  'drive',
#  'on',
#  'the',
#  'right-hand',
#  'side',
#  'of',
#  'the',
#  'road',
#  '.',
#  'Brazil',
#  'has',
#  'a',
#  'large',
#  'coastline',
#  'on',
#  'the',
#  'eastern',
#  'side',
#  'of',
#  'South',
#  'America']

# %%
# finding the frequency distinct in the tokens
# Importing FreqDist library from nltk and passing token into FreqDist
from nltk.probability import FreqDist
fdist = FreqDist(token)
fdist
# Out:
# FreqDist({'the': 3, 'Brazil': 2, 'on': 2, 'side': 2, 'of': 2, 'In': 1, 'they': 1, 'drive': 1, 'right-hand': 1, 'road': 1, ...})

# %%
# To find the frequency of top 10 words
fdist1 = fdist.most_common(10)
fdist1
# Out:
# [('the', 3),
#  ('Brazil', 2),
#  ('on', 2),
#  ('side', 2),
#  ('of', 2),
#  ('In', 1),
#  ('they', 1),
#  ('drive', 1),
#  ('right-hand', 1),
#  ('road', 1)]

# %%
# Importing Porterstemmer from nltk library
# Checking for the word ‘giving’ 
from nltk.stem import PorterStemmer
pst = PorterStemmer()
pst.stem('Waiting')
# Out:
# 'wait'

# %%
# Checking for the list of words
stm = ["waited", "waiting", "waits"]
for word in stm :
   print(word+ ":" +pst.stem(word))
# Out:
# waited:wait
# waiting:wait
# waits:wait

# %%
# Importing LancasterStemmer from nltk
from nltk.stem import LancasterStemmer
lst = LancasterStemmer()
stm = ["giving", "given", "given", "gave"]
for word in stm :
 print(word+ ":" +lst.stem(word))
# Out:
# giving:giv
# given:giv
# given:giv
# gave:gav

# %%
# Importing Lemmatizer library from nltk
from nltk.stem import WordNetLemmatizer

import nltk
nltk.download('wordnet')
  
lemmatizer = WordNetLemmatizer() 
 
print('rocks :', lemmatizer.lemmatize('rocks')) 
print('corpora :', lemmatizer.lemmatize('corpora'))
# Out:
# [nltk_data] Downloading package wordnet to /home/jj/nltk_data...
# rocks : rock
# corpora : corpus

# %% [markdown]
# Stop Words
# “Stop words” are the most common words in a language like “the”, “a”, “at”, “for”, “above”, “on”, “is”, “all”. These words do not provide any meaning and are usually removed from texts. We can remove these stop words using nltk library

# %%
# importing stopwors from nltk library
from nltk import word_tokenize
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')

a = set(stopwords.words('english'))
text = 'Cristiano Ronaldo was born on February 5, 1985, in Funchal, Madeira, Portugal.'
text1 = word_tokenize(text.lower())
print(text1)
stopwords = [x for x in text1 if x not in a]
print(stopwords)
# Out:
# [nltk_data] Downloading package stopwords to /home/jj/nltk_data...
# ['cristiano', 'ronaldo', 'was', 'born', 'on', 'february', '5', ',', '1985', ',', 'in', 'funchal', ',', 'madeira', ',', 'portugal', '.']
# ['cristiano', 'ronaldo', 'born', 'february', '5', ',', '1985', ',', 'funchal', ',', 'madeira', ',', 'portugal', '.']
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# Part-of-speech tagging is used to assign parts of speech to each word of a given text (such as nouns, verbs, pronouns, adverbs, conjunction, adjectives, interjection) based on its definition and its context. There are many tools available for POS taggers and some of the widely used taggers are NLTK, Spacy, TextBlob, Standford CoreNLP, etc.
#
# ![image.png](attachment:image.png)

# %%
import nltk
nltk.download('averaged_perceptron_tagger')


text = 'vote to choose a particular man or a group (party) to represent them in parliament'
#Tokenize the text
tex = word_tokenize(text)
for token in tex:
    print(nltk.pos_tag([token]))
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/jj/nltk_data...
# [('vote', 'NN')]
# [('to', 'TO')]
# [('choose', 'NN')]
# [('a', 'DT')]
# [('particular', 'JJ')]
# [('man', 'NN')]
# [('or', 'CC')]
# [('a', 'DT')]
# [('group', 'NN')]
# [('(', '(')]
# [('party', 'NN')]
# [(')', ')')]
# [('to', 'TO')]
# [('represent', 'NN')]
# [('them', 'PRP')]
# [('in', 'IN')]
# [('parliament', 'NN')]
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %% [markdown]
# Named entity recognition
# It is the process of detecting the named entities such as the person name, the location name, the company name, the quantities and the monetary value.

# %%
import nltk
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /home/jj/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data] Downloading package words to /home/jj/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# True

# %%
# !pip install svgling
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Ignoring invalid distribution -cxt (/home/jj/.local/lib/python3.10/site-packages)
# Collecting svgling
#   Downloading svgling-0.4.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting svgwrite (from svgling)
#   Downloading svgwrite-1.4.3-py3-none-any.whl.metadata (8.8 kB)
# Downloading svgling-0.4.0-py3-none-any.whl (23 kB)
# Downloading svgwrite-1.4.3-py3-none-any.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.1/67.1 kB 556.1 kB/s eta 0:00:00a 0:00:01
# WARNING: Ignoring invalid distribution -cxt (/home/jj/.local/lib/python3.10/site-packages)
# Installing collected packages: svgwrite, svgling
# Successfully installed svgling-0.4.0 svgwrite-1.4.3

# %%
text = 'Google’s CEO Sundar Pichai introduced the new Pixel at Minnesota Roi Centre Event'
#importing chunk library from nltk
from nltk import ne_chunk
# tokenize and POS Tagging before doing chunk
token = word_tokenize(text)
tags = nltk.pos_tag(token)
chunk = ne_chunk(tags)
chunk
# Out:
# Tree('S', [Tree('PERSON', [('Google', 'NNP')]), ('’', 'NNP'), ('s', 'VBD'), Tree('ORGANIZATION', [('CEO', 'NNP'), ('Sundar', 'NNP'), ('Pichai', 'NNP')]), ('introduced', 'VBD'), ('the', 'DT'), ('new', 'JJ'), ('Pixel', 'NNP'), ('at', 'IN'), Tree('ORGANIZATION', [('Minnesota', 'NNP'), ('Roi', 'NNP'), ('Centre', 'NNP')]), ('Event', 'NNP')])
